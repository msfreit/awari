# %%
# pip install pymongo
# pip install pymongo[srv]

from pymongo import MongoClient
import pandas as pd
client = MongoClient("mongodb+srv://revisapp-admin:f645HbS2AcypdWbG@cluster0.hmkez.mongodb.net/revisapp-mat?retryWrites=true&w=majority")
database = client["revisapp"]
collection = database["questions"]

# %%
query = {}

query["subjectName"] = u"matematica"
query["tags"] = u"\u00C1lgebra"

projection = {}

projection["content"] = u"$content"
projection["subjectName"] = u"$subjectName"
projection["tags"] = u"$tags"
projection["_id"] = 0

sort = [ (u"tags", -1) ]

cursor = collection.find(query, projection = projection, sort = sort)
questoes = list(cursor)
questoes
# Out:
# [{'content': '<p><img height="319" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_base/1_ddae2d3a265bac7a7949b4d77d6c0b67_14c50c03801b4ce62ecbcd423d7a6987.png" width="293"></p> <p>&nbsp; &nbsp; &nbsp;</p> <p>&nbsp; &nbsp; O diagrama acima mostra dois conjuntos de ruas de mão única que se cruzam no centro de uma cidade, nos pontos A, B, C e D. Nesse diagrama, as constantes a<sub>1</sub>, a<sub>2</sub>, a<sub>3</sub> e a<sub>4</sub> representam as quantidades de automóveis que entram, por hora, na região do centro pelas quatro ruas indicadas, e b<sub>1</sub>, b<sub>2</sub>, b<sub>3</sub> e b<sub>4</sub>, representam as quantidades de automóveis que saem do centro. As incógnitas x, y, z e w representam quantidades desconhecidas de automóveis que fluem pelos respectivos trechos no centro. Em cada cruzamento, o número de veículos que entra é igual ao número de veículos que sai, ou seja, as seguintes relações são válidas.</p> <p>&nbsp;</p> <p><img height="82" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_base/1_478f2ed44a04666fca1d7740d669ac9f_248423bb2a0f960d1dd71fc69f5d3ab7.png" width="190"></p> <p>&nbsp;</p> <p>Com base nas informações apresentadas, julgue o&nbsp;item.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Sequências']},
#  {'content': '<p>Num certo dia do mês de novembro de 2015, seis barracas da Feirinha de Artesanato da Pajuçara vendiam castanhas de caju em embalagens com pesos variados de acordo com a tabela.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Médias']},
#  {'content': '<p>Determine a solução da inequação&nbsp;<img src="https://img.estuda.com/temp/formula_7135a20f0078c0edbc4aaa1bce721838.png?zdn">&nbsp;dentre as apontadas nas alternativas a seguir.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Inequações Inequações polinomiais']},
#  {'content': '<p>Considere A uma matriz real quadrada de ordem 2, cujo determinante (det) é igual a 5, e A<sup>T</sup> a matriz transposta de A. Sabendo-se que x é um número real, o conjunto solução da inequação det(3<em>A</em>)x<sup>2 </sup>+&nbsp;det(2A·A<sup>T</sup>)x&nbsp;&gt; 0&nbsp;é</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Inequações Inequações polinomiais']},
#  {'content': '<p>Um grupo de estudantes fará uma excursão e alugará ônibus para transportá-lo. A transportadora dispõe de ônibus em dois tamanhos, pequeno e grande. O pequeno tem capacidade para 24 pessoas, ao custo total de R$ 500,00. O grande tem capacidade para 40 pessoas, ao custo total de R$ 800,00. Sabe-se que pelo menos 120 estudantes participarão da excursão e que o grupo não quer gastar mais do que R$ 4.000,00 com o aluguel dos ônibus.</p>\n<p>&nbsp;</p>\n<p>Sendo x o número de ônibus pequenos e y o número de ônibus grandes que serão alugados, o par ordenado (x, y) terá que pertencer, necessariamente, ao conjunto solução do sistema de inequações</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Inequação do Primeiro Grau Inequações Inequações polinomiais']},
#  {'content': '<p>Considere os polinômios&nbsp;<img src="https://img.estuda.com/temp/formula_35e3ad8732ec6d347a2f5406b59dfc23.png?zdn"></p> <p>&nbsp;</p> <p>Para que p(x) seja divisível por q(x), é necessário que m seja igual a</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função Polinomial']},
#  {'content': '<p>Sobre o sistema&nbsp;<img src="https://img.estuda.com/temp/formula_32297329e2f86f65d7a8a3a09ae61f2e.png?zdn">&nbsp;pode-se afirmar que o valor de&nbsp;</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função Polinomial']},
#  {'content': '<p>Este gráfico mostra uma análise da cotação do dólar do dia 23 ao dia 28 de março de 2016.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função Gráficos']},
#  {'content': '<p>Seja 𝒇: 𝑹 → 𝑹 definida por</p> <p>&nbsp;</p> <p><img src="https://img.estuda.com/temp/formula_d5290902a0bee2c946905047ff650668.png?zdn">,&nbsp;o valor de&nbsp;<img src="https://img.estuda.com/temp/formula_84329aabc41498a963c845c5fd261b09.png?zdn"> é:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Função Funções Definidas por Várias Sentenças']},
#  {'content': '<p>Três pessoas, X, Y e Z tinham a mesma quantia em reais. X, de início, gastou 99 reais. Y deu uma parte de sua quantia para Z, e o dobro dessa parte, para X. Com essas novas quantias em reais, as três pessoas saíram para as compras e X gastou o quadrado da diferença entre 4 reais e o que Y havia dado para Z. &nbsp;Y e Z gastaram, cada uma, a diferença entre o quadrado doque Y havia dado a Z e 4 reais. Após esses gastos, a soma das quantias de X e Z era igual ao dobro da de Y.</p>\n<p>&nbsp;</p>\n<p>É correto afirmar que X gastou no total, em reais,</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Função Funções Definidas por Várias Sentenças']},
#  {'content': '<p>Uma empresa de informática constatou que o custo total C(x) em reais para produzir seus equipamentos é dado pela função C(x) = det A + det B-10x +&nbsp;2 , na qual x é o número de equipamentos produzidos, com&nbsp;<img src="https://img.estuda.com/temp/formula_ff3a90ffa0dee47061d6a3ac11981a2c.png?zdn">&nbsp;e&nbsp;<img src="https://img.estuda.com/temp/formula_edb66b3663a83d61e31bc00eeafdc393.png?zdn"></p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função Função Quadrática']},
#  {'content': '<p>Na função real definida,&nbsp;<img src="https://img.estuda.com/temp/formula_8f786e2efc4add1fa46e92452b26cfc2.png?zdn">,&nbsp;f (0,01) vale:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função Função Modular']},
#  {'content': '<p>Dadas as matrizes&nbsp;<img class="formula" src="sis_questoes/formulas/09100cfdc838c897e6ad933494156b77.png?latex=A%3D%5Cleft(%5Cbegin%7Bmatrix%7D2%263%5C%5C5%261%5Cend%7Bmatrix%7D%5Cright)" border="0">&nbsp;e&nbsp;<img class="formula" src="sis_questoes/formulas/fb88bd947de96d208867b1b3b154fb81.png?latex=B%3D%5Cleft(%5Cbegin%7Bmatrix%7D3%261%5C%5C2%261%5Cend%7Bmatrix%7D%5Cright)" border="0"><strong></strong>, o valor de (A<sup>2</sup> – B<sup>2</sup>)<sup>t</sup> é</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função Função Exponencial']},
#  {'content': 'A solução racional do sistema&nbsp;<sub><img src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_0ad60dcda41eb7f8fade90e9d2e95871_27ins.jpg" alt="">&nbsp;</sub>pertence ao&nbsp;intervalo:<br>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função Função Exponencial']},
#  {'content': 'Considerando-se os números reais x, y e z tais que 2y – x = 3,&nbsp;3y + z = 7 e x ≥ y , o valor máximo de z – y é igual a:<br>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função Função Afim']},
#  {'content': '<p>Um bebê nasceu com 2,1kg e ganhou 150g por semana durante 6 semanas. Nas 4 semanas seguintes, ele perdeu peso a uma velocidade constante, perdendo ao todo&nbsp;<img src="https://img.estuda.com/temp/formula_22417f146ced89939510e270d4201b28.png?zdn">&nbsp;da sua massa. Nessas 10 semanas, sua massa m, em kg, pode ser descrita em função do tempo t, em semanas, por</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função']},
#  {'content': '<p>Dada a matriz&nbsp;<img src="https://img.estuda.com/temp/formula_6c36d3ef259167824b5587c2832cf05a.png?zdn">&nbsp;e a função f, definida no conjunto das matrizes 2 x 2 por f(X) = X<sup>2</sup> – 2X, então f(A) é</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função']},
#  {'content': 'Um comerciante comprou um lote de um produto A por R$&nbsp;1.000,00 e outro, de um produto B, por R$ 3.000,00 e planeja&nbsp;vendê-los, durante um certo período de tempo, em kits contendo&nbsp;um item de cada produto, descartando o que não for&nbsp;vendido ao final do período. Cada kit é vendido ao preço de &nbsp;R$ 25,00, correspondendo a R$ 10,00 do produto A e R$&nbsp;15,00 do B. Tendo em vista estas condições, o número mínimo&nbsp;de kits que o comerciante precisa vender, para que o lucro&nbsp;obtido com o produto B seja maior do que com o A, é:<br>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função']},
#  {'content': '<p>Seja<em> f</em>&nbsp;uma função real definida por</p> <p>&nbsp;<img src="https://img.estuda.com/temp/formula_ba88ee9b61264b8588d851f94256c0f1.png?zdn"></p> <p>com&nbsp;<em>a,b∈ ℝ</em>.&nbsp;Sabendo que os limites&nbsp;<img src="https://img.estuda.com/temp/formula_2ec0ea52fe8c6e44acaea89a06852f20.png?zdn">&nbsp;existem, assinale a opção que apresenta&nbsp;<img src="https://img.estuda.com/temp/formula_e21fd57d4831cec01a0d687cd8c225c9.png?zdn"></p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função']},
#  {'content': '<p>Pedro e Maria com seus filhos Gabriel e João foram a uma clínica médica para uma revisão de saúde. Fazia parte da avaliação aferir o peso de cada um. A balança da clínica era muito antiga e tinha um defeito, só indicava pesos maiores que 60 kg</p> <p>Para resolver a pesagem, procedeu-se da seguinte maneira:</p> <p>&nbsp;</p> <p>Pesou-se</p> <p>&nbsp;</p> <p>• Pedro, Maria e Gabriel, totalizando 150 kg</p> <p>• Pedro, Gabriel e João, totalizando 117 kg</p> <p>• Maria, Gabriel e João, totalizando 97 kg</p> <p>• Pedro, Maria, Gabriel e João, totalizando 172 kg</p> <p>&nbsp;</p> <p>Com base nessas informações, é correto afirmar que</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Expressões algébricas']},
#  {'content': 'Considere o polinômio <em>p</em>(x) = det <em>A</em> , onde<br>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Equações Equações polinomiais Polinomial']},
#  {'content': '<p>Dadas as matrizes:</p> <p><img src="https://img.estuda.com/temp/formula_6ac3ef86fcde9f1305bcb60a20e13c75.png?zdn"></p> <p>O quociente da divisão do polinômio p(x) = determinante(A - Ix)&nbsp;pelo polinômio q(x) = x - 2&nbsp;é:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Equações Equações polinomiais Polinomial']},
#  {'content': '<p>Há números que satisfazem à seguinte igualdade: “<em>O quadrado do logaritmo decimal de um número é igual ao&nbsp;</em><em>logaritmo decimal do quadrado desse mesmo número</em>”. A soma dos valores reais dos números que satisfazem essa igualdade é</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Equações Equações polinomiais Logarítmica']},
#  {'content': '<p>A solução do sistema&nbsp;<img height="49" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_2df0c53d3140e172391b0d345b4cd3db_cbf96365e0933de622b1f38a7dfe5c74.png" width="156">&nbsp;é</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Equações Equações polinomiais Logarítmica']},
#  {'content': '<p>Há seis anos, os nanotubos eram utilizados em laboratórios acadêmicos ou industriais interessados em nanociência e nanotecnologia. O preço comercial dos nanotubos era, então, extremamente elevado. Enquanto uma empresa belga vendia o grama de nanotubos por 500 euros, uma empresa americana vendia por 500 dólares.</p>\n<p><small>(www.inovacao.unicamp.br – Acesso em 13.03.2010.)</small></p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Equações Equações polinomiais Função']},
#  {'content': '<p>Daqui a 3 anos, a idade de um pai será a soma das idades que terão sua esposa e seu filho. Quando a esposa nasceu, a idade do pai era:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Equações Equações polinomiais']},
#  {'content': '<p>Seja f(x)&nbsp;uma função tal que para todo número real&nbsp;<em>x</em>&nbsp;temos que xf (x - 1) = (x - 3) f(x) + 3. Então, f(1) é igual a</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Equações Equações polinomiais']},
#  {'content': '<p>&nbsp; Sabe-se que os primeiros registros feitos pelos seres humanos eram marcados em paredes, folhas de palmeiras, tijolos de barro, tábuas de madeira. A primeira inovação foi o papiro, que tinha como matéria-prima uma planta. Depois ele foi substituído pelo pergaminho – feito de pele de animais –, que tinha maior durabilidade e que tornava a escrita mais fácil.</p> <p>&nbsp;&nbsp;No século II, a partir do córtex de plantas, tecidos velhos e fragmentos de rede de pesca, os chineses inventaram o papel.</p> <p>&nbsp;&nbsp;de de pesca, os chineses inventaram o papel. Em 1448, Johann Fust, juntamente com Gutenberg, fundou a Werk der Buchei (Fábrica de Livros), onde foi publicada a Bíblia de Gutenberg, livro que tinha 42 linhas. O aumento da oferta de papel e o aprimoramento das técnicas de impressão em larga escala ajudaram a consolidar o livro como veículo de informação e entretenimento.</p> <p>&nbsp;&nbsp;Em 1971, a tecnologia inovou o mundo da leitura com os e-books, livros digitais que podem ser lidos em vários aparelhos eletrônicos.</p> <p><small>Disponível em: . Acesso em: 14 fev. 17. (Parcial e adaptado.)</small></p> <p>&nbsp;</p> <p>Um livro pode ter um papel importante em narrativas de terror. Muitos escritores criam, dentro das próprias histórias, livros com determinadas características, como por exemplo: conter monstros aprisionados, certas palavras que, quando pronunciadas, provocam destruição, páginas de pele humana, letras escritas em sangue. Um exemplo clássico é o Necronomicon, livro de presença frequente nos contos do escritor estadunidense Howard Philip Lovecraft, usado para ressuscitar mortos e contatar seres sobrenaturais. Suponha um admirador de Lovecraft que também é professor de Matemática. Ele cria uma série de histórias sobre um livro amaldiçoado, cuja capa traz o seguinte sistema de equações escrito com sangue:&nbsp;</p> <p>&nbsp;</p> <p><img border="0" class="formula" src="sis_questoes/formulas/9afc5f10f9ab942bba9432bdba1a1c39.png?latex=%5Cfrac%7By%7D%7Bx%7D%3D4"></p> <p><img border="0" class="formula" src="sis_questoes/formulas/9973d0e6a13d40b65481c8b7b6380ae6.png?latex=%5Ctext%7B5y%3D12x%20%2B%20%5Cmid%20d%20%5Cmid%7D"></p> <p><img border="0" class="formula" src="sis_questoes/formulas/da65eb8f801fcd00a9fb4801db23a663.png?latex=d%3D%5Csqrt%7B144%7D"></p> <p>&nbsp;</p> <p>A narrativa diz que o livro não deve ser aberto, pois algo terrível acontecerá àquele que o fizer. Entretanto, poderá haver aquele que decidirá abri-lo e, para tanto, será necessário descobrir o valor de y que é</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Equações Equações polinomiais']},
#  {'content': '<p>A apresentação de um show de Rock gerou uma receita de R$ 11.000,00. Havia dois tipos de ingresso: um era vendido por R$ 20,00 e o outro R$ 40,00.</p>\n<p>&nbsp;</p>\n<p>Sabendo-se que foram vendidos ao todo 400 ingressos, podemos concluir que o número de ingressos vendidos a R$ 20,00 foi de</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Equações Equações polinomiais']},
#  {'content': 'Julinho tinha 40 figurinhas e desejava vendê-las. Ele vendeu algumas dessas figurinhas por R$ 0,50 cada unidade. Como não houve mais compradores, ele resolveu abaixar o preço de cada figurinha para R$ 0,30 e, dessa forma, conseguiu vender todas as figurinhas restantes. Com a venda das 40 figurinhas, Julinho arrecadou R$ 15,60. <br>A quantidade de figurinhas que foram vendidas por R$ 0,30 é um número múltiplo de&nbsp;<br>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Equações Equações polinomiais']},
#  {'content': '<p>Sobre equações algébricas, considere as seguintes afirmações:</p>\n<p>&nbsp;</p>\n<p>l Na equação 2x³ - 9x² + 10x - 3 = 0, sabendo que a,b e &nbsp;são raízes reais, o valor de&nbsp;<img class="formula" src="sis_questoes/formulas/a2b0ee41dcf8202d146e6d844e22c173.png?latex=log_%7B%5Cfrac%7B1%7D%7B9%7D%7D%5Cleft(%5Cfrac%7B1%7D%7Bab%7D%2B%5Cfrac%7B1%7D%7Bbc%7D%2B%5Cfrac%7B1%7D%7Bac%7D%5Cright)" border="0">&nbsp;é -1/2.&nbsp;</p>\n<p>ll Um recipiente cônico tem 8dm de altura. Seu espaço interior é ocupado por uma esfera cujo raio tem a metade da medida do raio do cone e por 60<img class="formula" src="sis_questoes/formulas/4f08e3dba63dc6d40b22952c7a9dac6d.png?latex=%5Cpi" border="0">dm³ de água. Então, os valores inteiros da medida do raio do recipiente cônico e do raio da esfera (em dm) são números múltiplos de 3.</p>\n<p>lll A equação x³ - 3x² - 4x + 12 = 0 tem raízes reais a,b e c&nbsp;Então, o determinante da matriz&nbsp;<img class="formula" src="sis_questoes/formulas/a6a9b14e8b627bdb3c6e8dfbc3439c88.png?latex=%5Cleft(%5Cbegin%7Bmatrix%7D0%260%26c%5C%5C0%26b%26b%5C%5C0%26a%26c%5Cend%7Bmatrix%7D%5Cright)" border="0">&nbsp;vale - 12.&nbsp;</p>\n<p>&nbsp;</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Equações Equações polinomiais']},
#  {'content': '<p>Considere a equação A(t)X = B(t), t ∈ R, em que&nbsp;<img class="formula" src="sis_questoes/formulas/60a7534116442e910c0acc291a40abb9.png?latex=A%5Cleft(t%5Cright)%3D%5Cleft%5B%5Cbegin%7Bmatrix%7D2e%5E%7B-2t%7D%26-e%5E%7B2t%7D%26-1%5C%5C-1%261%261%5C%5C-3%261%262%5Cend%7Bmatrix%7D%5Cright%5D%2CX%3D%5Cleft%5B%5Cbegin%7Bmatrix%7D%5Cbegin%7Bmatrix%7Dx%5C%5Cz%5Cend%7Bmatrix%7Dy%5C%5C%5Cend%7Bmatrix%7D%5Cright%5DB%5Cleft(t%5Cright)%3D%5Cleft%5B%5Cbegin%7Bmatrix%7De%5Et%5C%5C0%5Cend%7Bmatrix%7D-%5Csqrt%7B2%7D%5Cright%5D" border="0">&nbsp;Sabendo que det A(t) = 1 e t ≠ 0, os valores de x, y e z são, respectivamente,&nbsp;</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Equações Equações polinomiais']},
#  {'content': '<p>&nbsp;&nbsp;&nbsp; Ao se encerrarem as inscrições para o concurso vestibular de duas instituições, X e Y, verificou-se que 5 680 pessoas estavam inscritas. Sabe-se que <sub><img alt="" class="" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_964dee790d0788d52b9b0c84b489beab_44.png"></sub>delas inscreveram-se em ambos os concursos e que o número de candidatos inscritos para a instituição X excedia em 600 o número de inscritos para a instituição Y. O número de candidatos inscritos na instituição Y foi:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Equações Equações polinomiais']},
#  {'content': '<p>O sistema a seguir representa as quantias que dois amigos possuem, sendo x a quantia de Paulo e y a quantia de Luiz:&nbsp;<img src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_f8ce5ee5d67f879da32badb09c368c1d_10.png">.&nbsp; A&nbsp;<span>diferença entre as duas quantias é </span><span>igual a</span></p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Equações Equações polinomiais']},
#  {'content': 'Sabendo-se que&nbsp;<em>a</em><sub>4</sub>,&nbsp;<em>a</em><sub>5</sub>,<em>&nbsp;a</em><sub>6</sub>&nbsp;são termos de uma sequência numérica e que<br>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Equações Equações polinomiais']},
#  {'content': '<p>Para que o sistema de equações&nbsp;<img class="formula" src="sis_questoes/formulas/9e55ab74052583a4b13d64e2842299e6.png?latex=%5Cbigg%5C%7B%5Cbegin%7Bmatrix%7Dx%5E2-6x%2By%5E2%2B8y%3D24%5C%5Cx%5E2%2By%5E2%3Dk%5Cend%7Bmatrix%7D" border="0">&nbsp;tenha, pelo menos, uma solução real, o valor da constante k deve satisfazer a condição</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Equação do Segundo Grau Equações Equações polinomiais']},
#  {'content': '<p>Resolvendo o sistema de equação do primeiro grau&nbsp;<img src="https://img.estuda.com/temp/formula_00d3cc49b155cebbd2d1fad0b0794560.png?zdn">&nbsp;temos como solução:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Equação do Primeiro Grau Equações Equações polinomiais']},
#  {'content': '<p>Jorge precisa comprar 5 kg de um certo produto que é vendido em 3 embalagens:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Equação do Primeiro Grau Equações Equações polinomiais']},
#  {'content': '<p><img height="70" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_4e052b91fd52c160cbe2ac19c63637ad_8bffd2412ba83c51aee79dd01a17f8e4.png" width="117"></p> <p>A tabela mostra quanto, de certas vitaminas, há em cada 100g dos alimentos X, Y e Z. Para que uma pessoa, consumindo esses alimentos, possa ingerir 16mg de vitamina B<sub>3</sub>, 90mg de vitamina C e 15mg de vitamina E, será preciso consumir uma quantidade de alimento igual a</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Equação do Primeiro Grau Equações Equações polinomiais']},
#  {'content': '<p>Considere que a soma dos preços unitários das caixas de três medicamentos A, B e C seja R$ 105,00. Sabendo que o preço da caixa do medicamento B é a média aritmética dos preços das caixas dos medicamentos A e C, e que a caixa do medicamento C é R$ 30,00 mais cara que a caixa do medicamento A, a diferença positiva entre os preços das caixas dos medicamentos C e B é</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Aritmética Médias']},
#  {'content': '<p>Considere, a seguir, uma tabela com as notas de quatro alunos em três avaliações e a matriz M formada pelos dados dessa tabela.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Aritmética Médias']},
#  {'content': '<p>Um grupo de 5 estudantes teve dois de seus integrantes substituídos. A soma das idades desses dois estudantes era 45 anos. Com a chegada dos substitutos a média das idades do grupo aumentou 2 anos.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Aritmética Médias']},
#  {'content': '<p>Um padeiro acabou de receber de um fornecedor três sacos de farinha de diferentes tamanhos.</p> <p>&nbsp;</p> <p>Sabendo que o terceiro e o segundo sacos, juntos, têm 50 quilogramas, que o primeiro e o segundo, juntos, têm 45 quilogramas e que o primeiro e o terceiro, juntos, têm 55 quilogramas, a quantia total de farinha que acabou de receber, em quilogramas, foi</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Em uma clínica vascular, trabalham oito médicos. A cada dois anos, os médicos elegem um, dentre eles, para ser o diretor da clínica. A votação é aberta, e cada médico pode votar em até três pessoas, por voto direto. Enumerando os médicos de 1 a 8, a matriz a seguir representa a votação, onde a<sub>ij</sub> = 1 se o médico i votou no médico j, e a<sub>ij</sub> = 0, caso contrário:</p> <p style="text-align: center;"><img height="271" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_0882851d2509295e61e6ddcace33be00_1518172.jpg.png" width="282"></p> <p style="text-align: left;">Qual o número do médico que ganhou a eleição?</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>João, Sílvia e Pedro são funcionários de uma empresa.</p> <p>&nbsp;</p> <p>Considere as matrizes:</p> <p>&nbsp;</p> <p><img src="https://img.estuda.com/temp/formula_f83eb3e4084fd77185e6c17e41e1d92d.png?zdn">&nbsp;em que:</p> <p>&nbsp;</p> <p>• a matriz A representa o valor, em reais, recebido por hora trabalhada de João, Sílvia e Pedro, respectivamente;</p> <p>• a matriz B representa a quantidade de horas trabalhadas por semana dos mesmos funcionários, em cada uma das quatro primeiras semanas no mês de julho de 2018;</p> <p>• na matriz B, as linhas 1 a 3 são para João, Sílvia e Pedro, respectivamente; e as colunas de 1 a 4 são, nessa ordem, para as quatro primeiras semanas do mês de julho, de modo que, por exemplo, o elemento b<sub>13 </sub>é a quantidade de horas que João trabalhou na terceira semana desse mês.</p> <p>&nbsp;</p> <p>O valor pago pela empresa pelas horas trabalhadas por esses três funcionários na segunda semana de julho de 2018 será</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>&nbsp;&nbsp;&nbsp; Alexsandra foi com sua amiga Carol a uma loja de vestuário em promoção. Estavam à venda todas as blusas por um mesmo valor, assim como qualquer calça custava outro determinado valor. Alexsandra adquiriu duas blusas e uma calça por R$180,00. Já Carol comprou três blusas e duas calças e gastou um valor de R$320,00. Determine o preço de uma blusa e uma calça juntas.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>&nbsp; &nbsp; Um professor aplica, durante os cinco dias úteis de uma semana, testes com quatro questões de múltipla escolha a cinco alunos. Os resultados foram representados na matriz.</p> <p style="text-align: center;"><img height="85" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_177db0a0565acee27c6bd1d502ba3af4_1276998.jpg.png" width="176"></p> <p>&nbsp; &nbsp; Nessa matriz os elementos das linhas de 1&nbsp;a 5 representam as quantidades de questões acertadas pelos alunos Ana, Bruno, Carlos, Denis e Érica, respectivamente, enquanto que as colunas de 1 a 5 indicam os dias da semana, de segunda-feira a sexta-feira, respectivamente, em que os testes foram aplicados.</p> <p>&nbsp;</p> <p>O teste que apresentou maior quantidade de acertos foi o aplicado na</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Sabendo que <em>a</em> e <em>b</em> são números reais, considere a matriz quadrada de ordem&nbsp;<img src="https://img.estuda.com/temp/formula_24cccdfe8b9dddaed87bb893d7abcfc2.png?zdn"></p> <p>&nbsp;</p> <p style="text-align: left;"><img src="https://img.estuda.com/temp/formula_27f2e012d206e32326a472626b2ce1af.png?zdn"></p> <p style="text-align: left;">&nbsp;</p> <p>Se a soma dos elementos em cada linha da matriz <em>A</em> tem sempre o mesmo valor, então o determinante de <em>A</em> é igual a</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Dada a matriz&nbsp;<img src="https://img.estuda.com/temp/formula_ad47c2448026dc8b1b27b93172204736.png?zdn">&nbsp;e sendo&nbsp;<img src="https://img.estuda.com/temp/formula_30f7e21a29ce544bb5a507d6b4d32ad1.png?zdn">&nbsp;a soma dos elementos da primeira linha com a soma dos elementos da primeira coluna da matriz A é igual a</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Comprando dois milk shakes e um bolo gastamos R$13,00. Comprando um milk shake e dois bolos gastamos R$11,00.</p> <p>&nbsp;</p> <p>Quanto gastamos comprando um milk shake e um bolo?</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Dadas as matrizes&nbsp;<img src="https://img.estuda.com/temp/formula_7fcee0865630cb3da09b710f48287dc0.png?zdn">&nbsp;e&nbsp;<img src="https://img.estuda.com/temp/formula_48541809a8cb4c4b30d1945dc2e37b3d.png?zdn">, o produto A •&nbsp;B é a matriz&nbsp;</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>A solução do sistema&nbsp;<img src="https://img.estuda.com/temp/formula_6fddaae16cf92f4bcd8b745d5f543dda.png?zdn"></p> <p>é dada pelo terno ordenado</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Considere as matrizes <em>A&nbsp;</em>= [a<sub>ij</sub>]<sub>4x5</sub>, <em>B&nbsp;</em>= [b<sub>ij</sub>]<sub>5x9&nbsp;</sub>e <em>C&nbsp;</em>= [c<sub>ij</sub>], com <em>C = AB</em>.</p> <p>&nbsp;</p> <p>Podemos concluir que a matriz <em>C</em></p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>O preço de uma garrafa de água em um determinado supermercado é R$ 1,60. Além disso, a cada conjunto de 5 garrafas compradas, o cliente ganha uma extra, ou seja, leva 6 garrafas pelo preço de 5. De acordo com essas informações, qual é o maior número de garrafas que um cliente pode levar gastando no máximo R$ 30,00?&nbsp;</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>&nbsp; &nbsp; Uma dona de casa foi ao supermercado duas vezes em uma mesma semana para comprar arroz e feijão. Na primeira vez ela comprou três pacotes de feijão e dois pacotes de arroz, e na segunda vez, ela comprou um pacote de arroz e dois de feijão.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Numa lanchonete, o preço de um sanduíche corresponde ao dobro do preço de um suco. Dois sanduíches e três sucos custam, ao todo, R$ 45,50. Assim, quanto custariam três sanduíches e quatro sucos?</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>O custo (em reais) de uma corrida de táxi em certa cidade é constituído por um valor inicial fixo (em reais) somado a um valor (em reais) que varia linearmente com a distância percorrida (em km) nessa corrida. Sabendo-se que, em uma corrida na qual foram percorridos 10 km, a quantia cobrada foi de 34 reais e que, em outra corrida de 5 km, a quantia cobrada foi de 19 reais, então o valor que se deve pagar numa corrida de 15 km é:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Chegando ao destino de uma mesma viagem, os turistas <em>X</em> e <em>Y</em> alugarão, cada um deles, um carro. Fizeram, previamente, cotações com as mesmas três locadoras de automóveis da região. Os valores dos aluguéis estão representados pelas expressões dadas no quadro, sendo <em>K</em> o número de quilômetros percorridos, e <em>N&nbsp;</em>o número de diárias pagas pelo aluguel.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Dadas as matrizes&nbsp;<img src="https://img.estuda.com/temp/formula_9c22ce64ab0330258832a17f040bc783.png?zdn">&nbsp;o produto de <em>A.B</em> é:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Clarice e suas colegas de Engenharia resolveram organizar uma festa junina para arrecadar fundos para a formatura. Com esse intuito, montaram três quiosques, nos quais eram vendidos pipoca, cachorro quente e quentão. Ao término da festa, foi feito o levantamento das vendas nos três quiosques:</p> <p>&nbsp;</p> <p>No primeiro, foram vendidos 10 sacos de pipoca, 20 cachorros quentes e 10 copos de quentão.<br>\nNo segundo, foram vendidos 50 sacos de pipoca, 40 cachorros quentes e 20 copos de quentão.<br>\nNo terceiro, foram vendidos 20 sacos de pipoca, 10 cachorros quentes e 30 copos de quentão.<br>\nOs três quiosques lucraram R$ 150,00, R$ 450,00 e R$ 250,00 respectivamente.&nbsp;</p> <p>&nbsp;</p> <p>Assinale a alternativa que apresenta o preço de cada saco de pipoca, cachorro quente e copo de quentão, respectivamente.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>O quadrado mágico, um antigo jogo de tabuleiro, consiste em dispor números inteiros em uma matriz quadrada de modo que a soma dos elementos de cada linha, a soma dos elementos de cada coluna e a soma dos elementos das diagonais principal e secundária são números iguais.</p> <p>&nbsp;</p> <p>Considerando que a matriz&nbsp;<img src="https://img.estuda.com/temp/formula_61cdc24d50c39f6e49bcb99fcab99586.png?zdn">&nbsp;forma um&nbsp;quadrado mágico, julgue o&nbsp;item&nbsp;a seguir.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Observe a matriz:&nbsp;</p>\n<p><img class="formula" src="sis_questoes/formulas/4923ec7b13036d8777402b8a3940524f.png?latex=%5Cleft%5B%5Cbegin%7Bmatrix%7D3%2Bt%26-4%5C%5C3%26t-4%5Cend%7Bmatrix%7D%5Cright%5D" border="0"></p>\n<p>Para que o determinante dessa matriz seja nulo, o maior valor real de t deve ser igual a:&nbsp;</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Considere a matriz A<sub>nx9</sub> de nove colunas com números inteiros consecutivos, escrita a seguir.</p>\n<p>&nbsp;</p>\n<p><img src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_c16b3a44a1fcaee3db807dff0d8ed364_25.png"></p>\n<p>Se o número 18109 é um elemento da última linha, linha de ordem n, o número de linhas dessa matriz é:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Os consumidores X, Y e Z desejam trocar seus planos de internet móvel na tentativa de obterem um serviço de melhor qualidade. Após pesquisarem, escolheram uma operadora que oferece cinco planos para diferentes perfis, conforme apresentado no quadro.&nbsp;</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Uma empresa especializada no transporte fluvial de cargas utiliza três tipos distintos de barcos, cujas capacidades de carga, em toneladas, são identificadas por x, y e z. Sabe-se que 2x é igual a 3y, e que z é meia tonelada menor que x e duas toneladas maior que y. Nessas condições, x + y + z é igual a</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Considere o sistema linear nas variáveis reais x , y , z e w ,</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>A matriz A<sub>ij</sub>(2x3) tem elementos definidos pela expressão a<sub>ij</sub> = i<sup>3</sup> – j<sup>2</sup> . Portanto, a matriz A é</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Marta quer saber quanto pesam, juntos, os objetos X, Y e Z. Porém, não é possível apoiá-los na balança disponibilizada. Além disso, Marta não consegue carregar os três objetos simultaneamente. Dessa forma, inicialmente, ela sobe na balança carregando os objetos X e Y. A balança registra 70 kg. Em seguida, desce e sobe novamente, carregando, dessa vez, apenas o objeto Z. A balança&nbsp; registra então o total de 73 kg.</p> <p>&nbsp;</p> <p>Sabendo que o peso de Marta, individualmente, é 62 kg, determine a soma dos pesos dos objetos X, Y e Z.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Considere a matriz&nbsp;<img src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_5e96574b05f49320de8994aed19cf6a0_20.png" alt="">&nbsp;onde <em>a</em> e <em>b</em> são números reais. Se <em>A</em><sup>2</sup> = <em>A</em> e <em>A</em> é invertível, então</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Observe a matriz A, quadrada e de ordem três.</p> <p><img height="106" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_e191610665f537d2eef6aeb1ff2a9e22_12ee449f4c0674e0ca070a61e858fda0.png" width="236"></p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>José quer comprar chocolates e pipocas com os R$ 11,00 de sua mesada. Tem dinheiro certo para comprar dois chocolates e três pacotes de pipocas, mas faltam-lhe dois reais para comprar três chocolates e dois pacotes de pipocas. Nestas condições, podemos afirmar corretamente que um pacote de pipocas custa</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Dada as Matrizes&nbsp;<img src="https://img.estuda.com/temp/formula_ee9820b22d248ce44fc5ae7a3e710cee.png?zdn">&nbsp;calcule (A + B)<sup>t</sup></p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Dadas as matrizes&nbsp;<img src="https://img.estuda.com/temp/formula_4dbf3df5272d44eb8edbb3323ec8290d.png?zdn">&nbsp;e&nbsp;<img src="https://img.estuda.com/temp/formula_388a40e293a245303db5ad17f16e634d.png?zdn">&nbsp;e o produto A x B = C. Considerando, na matriz C, seus elementos com a correspondência dada pelo quadro a seguir:</p> <p><img height="45" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_eca1857128db4a9aa6670c6ec738e520_30573c7b6cdf141592e23ece5d9f77eb.png" width="528"></p> <p>as letras da palavra IFRN ocuparão, respectivamente, as posições</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>O sistema&nbsp;<img src="https://img.estuda.com/temp/formula_3a0fcc651c0083683ffde6d5ec03e639.png?zdn">&nbsp;pode ser apresentado como</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Qual das seguintes alternativas é a solução do sistema&nbsp;<img src="https://img.estuda.com/temp/formula_699e97def2acfd25a2ef00e79cfd1feb.png?zdn">?</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Qual é a inversa da matriz&nbsp;<img src="https://img.estuda.com/temp/formula_63ddc2d53e4e2c86456cd7112803979d.png?zdn">?</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Num jogo, foram sorteados 6 números para compor uma matriz M = ( m<sub>ij </sub>) de ordem 2 X 3. Após o sorteio, notou-se que esses números obedeceram à regra m<sub>ij </sub>= 4i – j. Assim, a matriz M é igual a _________.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Seja a matriz A<sub>3x3</sub> definida por A<sub>ij </sub>= 2i – 3j. O determinante da matriz vale:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>O governo de um país criou o Fundo da Soja e do Milho, que tem como expectativa inicial arrecadar, por ano, R$ 36,14 milhões para investimento em pesquisas relacionadas aos principais produtos da agricultura. Com isso, a cada operação de venda, seriam destinados ao Fundo R$ 0,28 por tonelada de soja e R$ 0,22 por tonelada de milho comercializadas. Para este ano, espera-se que as quantidades de toneladas produzidas, de soja e de milho, juntas, seja 150,5 milhões.<br>\n<br>\nFoi pedido a cinco funcionários do Fundo, André, Bruno, Caio, Douglas e Eduardo, que apresentassem um sistema que modelasse os dados apresentados. Cada funcionário apresentou um sistema diferente, considerando x e y como as quantidades de toneladas comercializadas, respectivamente, de soja e de milho. O resultado foi o seguinte:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Um lojista está fazendo um orçamento sobre o preço de determinada camiseta. A matriz A representa o preço, em reais, dessa camiseta de acordo com o tamanho: pequeno (P), médio (M) ou grande (G), em três lojas diferentes, e a matriz B representa a quantidade de camisetas, por tamanho, que o lojista pretende comprar.</p> <p><img height="79" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_33c29479780e5738bf79b49cd5f1c4ee_1012865.jpg.png" width="246"></p> <p>A diferença entre o maior e o menor orçamento é</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Considere as matrizes <em>M </em>e <em>N</em> abaixo.</p> <p>&nbsp;</p> <p><img src="https://img.estuda.com/temp/formula_03f12f2392bcd59b043ac78e1cede27b.png?zdn"></p> <p>&nbsp;</p> <p>Sabendo-se que&nbsp;<img src="https://img.estuda.com/temp/formula_b1ad27ba9a1104d6826edbb53af46ecb.png?zdn">&nbsp;onde <em>I</em> é a matriz identidade,&nbsp;podemos dizer que</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': 'Uma família fez uma pesquisa de mercado, nas lojas de eletrodomésticos,&nbsp;à procura de três produtos que desejava adquirir:&nbsp;uma TV, um freezer e uma churrasqueira. Em três das lojas&nbsp;pesquisadas, os preços de cada um dos produtos eram coincidentes&nbsp;entre si, mas nenhuma das lojas tinha os três produtos&nbsp;simultaneamente para a venda. A loja A vendia a churrasqueira&nbsp;e o freezer por R$ 1.288,00. A loja B vendia a TV e o freezer&nbsp;por R$ 3.698,00 e a loja C vendia a churrasqueira e a TV por&nbsp;R$ 2.588,00.&nbsp;<br><br>A família acabou comprando a TV, o freezer e a churrasqueira&nbsp;nestas três lojas. O valor total pago, em reais, pelos três produtos&nbsp;foi de<br>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Três amigos Samuel, Vitória e Júlia, foram a uma lanchonete.</p> <p>&nbsp;</p> <p>• Samuel tomou 1 guaraná, comeu 2 esfirras e pagou 5 reais.</p> <p>• Vitória tomou 2 guaranás, comeu 1 esfirra e pagou 4 reais.</p> <p>• Júlia tomou 2 guaranás, comeu 2 esfirras e pagou <strong>k</strong> reais.</p> <p>&nbsp;</p> <p>Considerando-se que cada um dos três pagou o valor exato do que consumiu, é correto afirmar que</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Três amigos, Abel, Bruno e Carlos, juntos possuem um total de 555 figurinhas. Sabe-se que Abel possui o triplo de Bruno menos 25 figurinhas, e que Bruno possui o dobro de Carlos mais 10 figurinhas.</p> <p>&nbsp;</p> <p>Desses amigos, o que possui mais tem</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p><img height="319" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_base/1_ddae2d3a265bac7a7949b4d77d6c0b67_14c50c03801b4ce62ecbcd423d7a6987.png" width="293"></p> <p>&nbsp; &nbsp; &nbsp;</p> <p>&nbsp; &nbsp; O diagrama acima mostra dois conjuntos de ruas de mão única que se cruzam no centro de uma cidade, nos pontos A, B, C e D. Nesse diagrama, as constantes a<sub>1</sub>, a<sub>2</sub>, a<sub>3</sub> e a<sub>4</sub> representam as quantidades de automóveis que entram, por hora, na região do centro pelas quatro ruas indicadas, e b<sub>1</sub>, b<sub>2</sub>, b<sub>3</sub> e b<sub>4</sub>, representam as quantidades de automóveis que saem do centro. As incógnitas x, y, z e w representam quantidades desconhecidas de automóveis que fluem pelos respectivos trechos no centro. Em cada cruzamento, o número de veículos que entra é igual ao número de veículos que sai, ou seja, as seguintes relações são válidas.</p> <p>&nbsp;</p> <p><img height="82" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_base/1_478f2ed44a04666fca1d7740d669ac9f_248423bb2a0f960d1dd71fc69f5d3ab7.png" width="190"></p> <p>&nbsp;</p> <p>Com base nas informações apresentadas, julgue o&nbsp;item.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Uma tropa realizou um exercício em que soldados, sargentos e oficiais executaram módulos padronizados de tiro, consumindo, individualmente, o número de munição estabelecido conforme o seu nível hierárquico. No primeiro dia atiraram <em>16</em> soldados, <em>8</em> sargentos e <em>4</em> oficiais, totalizando <em>96</em> munições; no segundo dia, <em>5</em> soldados, <em>4</em> sargentos e <em>3</em> oficiais, totalizando <em>38</em> munições; no terceiro dia, <em>16 </em>soldados, <em>4</em> sargentos e <em>1</em> oficial, totalizando <em>78</em> munições. Quantas munições foram usadas no quarto dia, quando atiraram <em>14</em> soldados, <em>8</em> sargentos e<em> 2</em> oficiais?</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Se&nbsp;<img src="https://img.estuda.com/temp/formula_70a1b0f062e4eb205472380a10abb82d.png?zdn">&nbsp;então&nbsp;<img src="https://img.estuda.com/temp/formula_4ca9e113741b6e3fdddb9539b9c06834.png?zdn">&nbsp;vale:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Qual o valor de <em>x</em>&nbsp;∈ <em>R</em>,&nbsp;para que a matriz abaixo não seja invertível?</p> <p><img src="https://img.estuda.com/temp/formula_03120b3e145071a4b7bc24b712033ae8.png?zdn"></p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Sabendo que <em>p</em>&nbsp;é um número real, considere a matriz&nbsp;<img src="https://img.estuda.com/temp/formula_d952a413e85fe55f2ee1cb80dc3175fa.png?zdn">&nbsp;e sua transposta&nbsp;<img src="https://img.estuda.com/temp/formula_7407874da118972a5fc555b572f36597.png?zdn"></p> <p>&nbsp;</p> <p>Se&nbsp;<img src="https://img.estuda.com/temp/formula_54458cb83a058fe7069de2de71000c78.png?zdn">&nbsp;é singular (não invertível), então</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Seja k um número real e&nbsp;<img src="https://img.estuda.com/temp/formula_3420ac699bc0aea081cde2aa0542da2a.png?zdn">&nbsp;um sistema de equações nas incógnitas x e y.</p> <p>&nbsp;</p> <p>Os valores de k para que a solução gráfica desse sistema pertença ao interior do terceiro quadrante do plano cartesiano são dados pelo intervalo</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Júnior compra mensalmente os medicamentos X, Y e Z. Comprando duas caixas de X, três de Y e uma de Z ele paga R$ 400,00; comprando uma caixa de X, duas de Y e duas de Z, ele paga R$ 360,00.</p> <p>&nbsp;</p> <p>Quanto Júnior pagará por cinco caixas de X, oito caixas de Y e quatro de Z?</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>Em uma empresa de venda de carros, são vendidos três modelos de carros, em três versões diferentes, e o faturamento pode ser escrito na forma matricial&nbsp;<img src="https://img.estuda.com/temp/formula_2a25ebb2d0a2c9b5e776dbaeac966a7e.png?zdn"></p> <p>&nbsp;</p> <p>Para que o sistema tenha soluções próprias, o valor de <em>k</em>&nbsp;é:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>A matriz Z<sub>6x6</sub> apresenta um comparativo do número de casos confirmados de zika no estado de São Paulo entre o 1° semestre de 2019 e o 1° semestre de 2018.</p> <p style="text-align: center;"><img height="113" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_000df8cee7e9116ac2b8044b39757067_4016640.jpg.png" width="235"></p> <p style="text-align: left;">Nessa matriz, cada elemento z<sub>ij</sub> indica a diferença entre o número de casos registrados no mês i de 2019 e o número de casos registrados no mês j de 2018, sendo que tanto para i como para j tem-se: 1 para janeiro, 2 para fevereiro e assim, sucessivamente, até 6 para junho.</p> <p style="text-align: left;">&nbsp;</p> <p style="text-align: left;">Segundo essa matriz, o número total de casos confirmados de zika no estado de São Paulo no 1° semestre de 2019, comparado ao 1° semestre de 2018, apresentou uma redução de</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
#  {'content': '<p>&nbsp; &nbsp; Uma empresa avaliou os cinco aparelhos de celulares (T<sub>1</sub>, T<sub>2</sub>, T<sub>3</sub>, T<sub>4</sub> e T<sub>5</sub>) mais vendidos no último ano, nos itens: câmera, custo-benefício, design, desempenho da bateria e tela, representados por I<sub>1</sub>, I<sub>2</sub>,I<sub>3</sub>,I<sub>4</sub> e I<sub>5</sub>, respectivamente. A empresa atribuiu notas de 0 a 10 para cada item avaliado e organizou essas notas em uma matriz<em> A</em>, em que cada elemento a<sub>ij</sub> significa a nota dada pela empresa ao aparelho T<sub>i</sub> no item I<sub>j</sub> . A empresa considera que o melhor aparelho de celular é aquele que obtém a maior soma das notas obtidas nos cinco itens avaliados.</p> <p style="text-align: center;"><img height="142" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_e906e242b1ea74f6e2cb9af27ec6b566_4142121.jpg.png" width="225"></p> <p style="text-align: left;">Com base nessas informações, o aparelho de celular que a empresa avaliou como sendo o melhor é o</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear']},
# ...
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função']},
#  {'content': '<p>O sindicato de trabalhadores de uma empresa sugere que o piso salarial da classe seja de R$ 1 800,00, propondo um aumento percentual fixo por cada ano dedicado ao trabalho. A expressão que corresponde à proposta salarial (s), em função do tempo de serviço (t), em anos, é s(t) = 1 800 •&nbsp;(1,03)<sup>t</sup>.<br>\nDe acordo com a proposta do sindicato, o salário de um profissional dessa empresa como 2 anos de tempo serviço será, em reais,</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função']},
#  {'content': '<p>A dona de um café compra caixas, contendo 60 brigadeiros, em uma doceira, ao custo de R$ 30,00 cada caixa. Ela vende, em média, 120 brigadeiros por dia, a R$ 1,20 a unidade. Qual o lucro médio diário que a dona desse café obtém com a venda desses brigadeiros?</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Equação do Primeiro Grau Equações Equações polinomiais']},
#  {'content': '<p>A “Chikungunya”, como a dengue e outras viroses, é uma doença que preocupa a população de modo geral. Admita-se, hipoteticamente, que, em janeiro de 2014, houve 37 casos de uma determinada doença, em fevereiro, 55 novos casos ocorreram, e assim por diante, com o número de novos casos aumentando a cada mês, como uma progressão aritmética.</p>\n<p>&nbsp;</p>\n<p>Continuando assim, o total de casos, ao longo desse ano, será</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Sequências']},
#  {'content': '<p>A Universidade Estadual de Goiás mudou seu sistema de avaliação e uma das mudanças é o cálculo da média final, que passou a ser dado por: média final&nbsp;<img border="0" class="formula" src="sis_questoes/formulas/331648a31659d9842c304d9b8ffffe23.png?latex=%3D%5Cfrac%7B2.N_1%2B3.N_2%7D%7B5%7D">&nbsp;, onde N<sub>1</sub> e N<sub>2</sub> são a primeira e segunda nota do aluno, respectivamente. Se um aluno tiver 5,0 e 7,0 na primeira e na segunda nota, respectivamente, a média final desse aluno será</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Médias Ponderada']},
#  {'content': '<p>Em um distrito de certo município, o número de habitantes, num raio de r quilômetros a partir do Centro de Saúde Municipal, é dado por P(r) = k · 2<sup>3.r</sup>, em que k é constante e r &gt; 0. Se há 1 536 habitantes num raio r = 3 km, o número de habitantes existentes num raio r = 4 km desse Centro de Saúde é igual a</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função Função Exponencial']},
#  {'content': '<p>Duas grandezas positivas x e y são inversamente proporcionais se existe uma correspondência bijetiva entre os valores de x e os valores de y e um número constante positivo k tal que, se o valor y é o correspondente do valor x então y.x = k. Nestas condições, se o valor y = 6 é o correspondente ao valor x = 25, então o valor y que corresponde ao valor x = 15 é</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função Função Bijetora Relações Binárias']},
#  {'content': '<p>Um objeto é lançado verticalmente, para cima, de forma que a altura alcançada h, medida em metros, e o tempo decorrido após o lançamento t, medido em segundos, estão relacionados pela equação h – 120t + 5t<sup>2</sup> = 0. Considerando h = 0 e t = 0 no instante do lançamento, então o tempo decorrido desde o lançamento até alcançar a altura máxima, e a altura máxima atingida são respectivamente&nbsp;</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função Função Quadrática']},
#  {'content': '<p>Uma indústria produz suprimentos para informática do tipo A, B e C, e cada suprimento é equipado com as peças p<sub>1</sub>, p<sub>2</sub> e p<sub>3</sub>, conforme a tabela I (suprimentos/peças).</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Equações Equações polinomiais']},
#  {'content': '<p>Uma pessoa obesa, pesando num certo momento 130 kg, recorre a uma dieta “milagrosa”, que promete perda de até 2,5 kg por semana. Suponhamos que essa pessoa perca realmente 2,5 kg por semana.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Sequências']},
#  {'content': '<p>O saldo de uma aplicação financeira após t meses de aplicação é dado por : S = 2000+ 40.t . Após quanto tempo de aplicação o saldo dobra de valor?</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função Função Afim']},
#  {'content': '<p>Considere a seguinte função de produção P = 10x<sup>2/3</sup>,&nbsp;em que P é o número de mesas produzidas por semana numa marcenaria (com certo numero fixo de empregados) e x o número de serras elétricas utilizadas. Quantas mesas serão produzidas por semana se forem utilizadas 8 serras?</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Equações Equações polinomiais Exponenciais']},
#  {'content': '<p>A receita diária de um estacionamento para automóveis é dada pela equação R = 100p - 5 p<sup>2</sup>,&nbsp;em que p é o preço cobrado por dia de estacionamento por carro. Quais os preços que devem ser cobrados para dar uma receita de R$ 375,00?</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Equação do Segundo Grau Equações Equações polinomiais']},
#  {'content': '<p>Considere a função f : IR → IR, definida por f (x) = ax + 6, com a ∈ IR. Se f (−3) = −6, então o valor de x para o qual f (x) = 12 está no intervalo</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função Função Afim']},
#  {'content': '<p>A expressão L = −2(5 − p) representa o lucro (L) na venda de uma mercadoria onde p é a quantidade de mercadorias vendidas. Com base nos dados, é <strong>CORRETO </strong>afirmar que o lucro será positivo para:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Equação do Primeiro Grau Equações Equações polinomiais']},
#  {'content': '<p>Assumindo que log(2)= 0,3 e log(5)= 0,7 , então o log(20) é:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Equações Equações polinomiais Logarítmica']},
#  {'content': '<p>Para pintar sua casa, Marcos encontra dois pintores: Antônio, que cobra um valor contratual de R$ 100,00 e mais R$ 10,00 por m<sup>2 </sup>de área pintada, e Benedito, que cobra R$ 200,00 no contrato e mais R$ 6,00 por m<sup>2</sup> de pintura. Acima de quantos m<sup>2</sup> de área pintada é mais econômico contratar Benedito?</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Inequação do Primeiro Grau Inequações Inequações polinomiais']},
#  {'content': '<p>Dados os conjuntos A = {0, 7, 1}; B = {x, y, 1} e A = B. Podemos afirmar que:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função']},
#  {'content': '<p>Apesar do grande número de acessos dos brasileiros às redes sociais, o Brasil ainda tem uma velocidade média de internet muito baixa, como pode ser observado no gráfico 2. Entre os países apresentados no gráfico 2, é correto afirmar que a média aritmética e a mediana dos dados, aproximada e respectivamente, são de</p> <p><img height="332" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_f4f53b95fa5275212013a2e6dd715aac_0b80fbd2cd0ce3b13e953b6007e29406.png" width="451"></p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Aritmética Médias']},
#  {'content': '<p>Com a popularização das redes sociais, para um vídeo tornar-se notável ou “viral” em poucas horas, bastam alguns milhares de compartilhamentos. Supondo que um vídeo tenha sido lançado na internet, e na primeira hora tenha 3.000 compartilhamentos, em 3 horas 12.000, e em 5 horas 48.000 compartilhamentos, em 10 horas o número de compartilhamentos será de</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Sequências']},
#  {'content': '<p>Na eleição do grêmio estudantil do IFSUL houve três candidatos à presidência: Maria, Renato e Pedro. O presidente é eleito pelos alunos através de voto secreto; cada aluno pode votar em apenas um dos candidatos, e todos os alunos do IFSUL votaram. Após a apuração dos votos, verificou-se que Maria e Renato juntos tiveram 2.230 votos, Maria e Pedro alcançaram 1.702 votos, e Renato e Pedro 1.940 votos.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Equação do Primeiro Grau Equações Equações polinomiais']},
#  {'content': '<p>O número log<sub>3</sub> 30 está entre</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função Função Logarítmica']},
#  {'content': '<p><img height="192" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_2a0fa528131b000c69bf66a4d29d6cd1_67e24c584cfb3f0eb6c19bbf60107e88.png" width="325"></p> <p>O gráfico mostra a evolução da taxa de mortalidade infantil no Brasil, na década passada. A média e a mediana dessas taxas são, respectivamente,</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Aritmética Médias']},
#  {'content': '<p style="text-align: left;">Admitindo-se que o número de animais de uma criação seja dado pela lei C(t) = 30. 2<sup>t</sup> , com t representando o tempo em anos, e considerando log2 = 0,30, é correto afirmar que o tempo necessário para que essa população atinja um total de 300 animais é de, aproximadamente,</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função Função Logarítmica']},
#  {'content': '<p><strong>TEXTO</strong></p> <p>&nbsp;</p> <p>O envio e o recebimento de informações sigilosas é uma necessidade antiga, que existe há centenas de anos. Com o surgimento da internet e sua consequente facilidade de transmitir dados de maneira precisa e extremamente rápida, a criptografia tornou-se uma ferramenta fundamental para permitir que apenas o emissor e o receptor tenham acesso livre à informação trabalhada. O termo criptografia surgiu da fusão das palavras gregas “kryptós” e “gráphein”, que significam “oculto” e “ escrever”, respectivamente. O sistema mais utilizado é o de chave de bit. Quanto mais bits forem utilizados, mais segura é a criptografia.</p> <p><small>Disponível em: http://www.infowester.com/criptografia.php. Acessado em: 03 de abril de 2015.</small></p> <p>&nbsp;</p> <p>Uma das técnicas utilizadas é a decodificação com a chave simétrica.</p> <p><img height="320" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_c7866dba3f86fd35ac53f759e01df733_c19fea24e1902aed235ab9f251728ba0.png" width="545"></p> <p>Caso um algoritmo use chave de 4 bits, por exemplo, apenas 16 chaves poderão ser utilizadas na decodificação. Caso use 5 bits, 32 chaves poderão ser utilizadas na decodificação e, caso use 6 bits, 64 chaves na decodificação. De acordo com estas informações, se utilizarmos 8 bits, quantas chaves poderão ser utilizadas na decodificação?</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Sequências']},
#  {'content': '<p><strong>TEXTO</strong></p> <p>O termo dinheiro de plástico é muitas vezes utilizado em reportagens sobre formas de pagamento e opções de crédito em geral. Dinheiro de plástico significa “cartão de crédito” ou “cartão de débito” que são utilizados para pagar contas ao invés do dinheiro em espécie. Dinheiro de plástico é portanto devido aos cartões serem feitos de plásticos e terem se tornado a principal forma de pagamento, devido a comodidade, segurança e atrativos das operadoras, em vários estabelecimentos.</p> <p><small>Disponível em: http://www.creditooudebito.com.br/o-que-e-dinheiro-de-plastico/. Acessado em: 03 de abril de 2015. </small></p> <p>&nbsp;</p> <p><strong>TEXTO&nbsp;</strong></p> <p>&nbsp;</p> <p>(...) Porém uma desvantagem é o juro abusivo cobrado no atraso do pagamento da fatura, conforme TABELA&nbsp;do Banco Central para o período de 13/03/2015 a 19/03/2015.</p> <p>&nbsp;</p> <p><strong>TABELA </strong></p> <p><img height="309" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_91734cdb5d225ebfcc9ae57fec7bba7f_8332847191559ad12f718b5fc75e30e8.png" width="461"></p> <p>De acordo com a TABELA&nbsp;podemos afirmar que a média mensal de juros cobrada por estes bancos é de aproximadamente:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Aritmética Médias']},
#  {'content': '<p><strong>TEXTO</strong></p> <p>&nbsp;</p> <p>A Secretaria Especial da Promoção da Igualdade Racial do Distrito Federal (Sepir/DF) lançou o Disque Racismo. O serviço público vai receber, acolher e acompanhar denúncias de caráter discriminatório étnico-raciais ocorridas no DF, além de oferecer assistências psicológica e jurídica às vítimas. Inédito no Brasil, o Disque Racismo é um serviço de proteção aos direitos das populações negra, indígena, quilombola, cigana e ribeirinha, e de zelo e manutenção das religiões de matrizes africanas. Segundo o secretário da Sepir, Viridiano Custódio Negrito, “os negros e pardos correspondem a 54% da população do DF. Com a iniciativa, o Distrito Federal se torna a primeira unidade da federação livre do racismo”.</p> <p><small>Fonte: http://www.rogeriocorreia.com.br/noticia/disque-racismo-e-lancado-e-vai-receber-e-acompanhar-denuncias-no-df/. Acesso em: 09 out. 2014.</small></p> <p>&nbsp;</p> <p><strong>TEXTO</strong></p> <p><img height="233" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_fc659228f7554b299e19f51d1f38aafb_ac18eed9dae4673cb590149d2fe0be52.png" width="419"></p> <p>O número do Disque Denúncia é o maior valor assumido pela função f(x) = - x<sup>2</sup> + 2x + 135. Então, podemos afirmar que o número é:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função Função Quadrática']},
#  {'content': '<p>A função σ(n) retorna a soma dos divisores positivos do número n, por exemplo:</p> <p>&nbsp;</p> <p>σ(6) = 1 + 2 + 3 + 6 = 12</p> <p>σ(10) = 1 + 2 + 5 + 10 = 18</p> <p>&nbsp;</p> <p>Dois números x e y são considerados quase amigos se σ(x) = σ(y) = x + y + 1. O número que é quase amigo do número 75 é o</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função Função Afim']},
#  {'content': '<p>O número de bactérias de uma cultura, t horas, após o início de um experimento, é dado pela expressão&nbsp;<img src="https://img.estuda.com/temp/formula_432d7d83010207655a9e5657f200127f.png?zdn"></p> <p>Considerando-se que x horas, após o início do experimento, a cultura tem 11700 bactérias, pode-se afirmar que x é igual a</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função']},
#  {'content': '<p>A média aritmética dos números que indicam os tamanhos das onze chuteiras de um time de futebol é 40. Se forem retiradas do cálculo duas das chuteiras, de tamanhos 37 e 43, a média dos números correspondentes às nove chuteiras restantes passa a ser <em><strong>n</strong></em>.</p> <p>O valor de <em><strong>n</strong></em> é igual a:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Aritmética Médias']},
#  {'content': '<p>Calcular um número <em><strong>n</strong></em>, cujo logaritmo na base 4 é igual a 1,5, equivale a resolver a seguinte equação:</p> <p>&nbsp;</p> <p><em><strong>n</strong></em> - (4)<sup>1,5</sup> = 0</p> <p>&nbsp;</p> <p>Desse modo, pode-se afirmar que <em><strong>n</strong></em> tem o seguinte valor:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Equações Equações polinomiais Logarítmica']},
#  {'content': '<p>Os resultados de uma avaliação escolar de vinte alunos de uma turma, em uma escala de 0 a 10,0 pontos, estão listados a seguir:</p> <p><img height="82" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_b0ecac59b4438dfb7e6d5c82b65f6aaf_787266.jpg.png" width="691"></p> <p>A média aritmética dos resultados dos vinte alunos é igual a:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Médias']},
#  {'content': '<p>O gráfico abaixo mostra o registro das temperaturas máximas e mínimas em uma cidade, nos primeiros 21 dias do mês de setembro de 2013.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Função']},
#  ...]

# %%
for questao in questoes:
    if questao["tags"][1] == "Sequências":
        print(questao)
# Out:
# {'content': '<p>Considere que (<em>a, b</em>, 3,<em> c</em>)&nbsp;é uma progressão aritmética de números reais, e que a soma de seus elementos é igual a 8.</p> <p>&nbsp;</p> <p>O produto dos elementos dessa progressão é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>A progressão geométrica (a<sub>1</sub>, a<sub>2</sub>, a<sub>3</sub>, ...)&nbsp;tem primeiro termo a<sub>1</sub> = 3/8&nbsp;e razão 5.&nbsp; A progressão geométrica&nbsp;(b<sub>1</sub>, b<sub>2</sub>, b<sub>3</sub>, ...) tem razão 5/2.</p> <p>&nbsp;</p> <p>Se a<sub>5</sub> = b<sub>4</sub>,&nbsp;então b<sub>1&nbsp;</sub>é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Considere o padrão de construção de triângulos com palitos, representado nas figuras abaixo.</p> <p style="text-align: center;"><img height="89" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_aee60ca5f7fa9b4638e44ac38489d88b_4154489.jpg.png" width="313"></p> <p style="text-align: left;">Na etapa n, serão utilizados 245 palitos. Nessas condições, n é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Uma progressão geométrica tem o seu primeiro termo e sua razão iguais a 1/2.</p> <p>&nbsp;</p> <p>O quinto termo dessa progressão é uma fração que, se escrita em forma percentual, é dada por</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>As idades de um jovem, de sua mãe e de sua avó estão, nessa ordem, em progressão geométrica de razão 9/4. Sabe-se que a avó possui 65 anos a mais que o neto.</p> <p>&nbsp;</p> <p>A idade, em anos, da mãe desse jovem é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>&nbsp; &nbsp; Em um município foi realizado um levantamento relativo ao número de médicos, obtendo-se os dados:</p> <p style="text-align: center;"><img height="102" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_36dc27b6964be0402276c80702155fc3_1440435.jpg.png" width="309"></p> <p style="text-align: left;">&nbsp; &nbsp; Tendo em vista a crescente demanda por atendimento médico na rede de saúde pública, pretende-se promover a expansão, a longo prazo, do número de médicos desse município, seguindo o comportamento de crescimento linear no período observado no quadro.</p> <p style="text-align: left;">&nbsp;</p> <p style="text-align: left;">Qual a previsão do número de médicos nesse município para o ano 2040?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>A figura a seguir exibe um pentágono em que quatro lados consecutivos têm comprimentos <em>a, b, c</em> e <em>d</em>.</p> <p>&nbsp;</p> <p>Se a sequência (<em>a, b, c, d</em>) é uma progressão geométrica de razão <img src="https://img.estuda.com/temp/formula_1c1200f6d92cb675944eb522a688595e.png?zdn"> então tan <em>θ</em> é igual a</p> <p style="text-align: center;"><img height="116" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_399b22e15af05e8940ac8a9f3ef78c22_1446604.jpg.png" width="172"></p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Se 1 + 4 + 7 + 10 + ... + N = 925, então o valor de N é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>O primeiro termo de uma progressão aritmética (P.A), em que a<sub>20</sub> = 84&nbsp;e a razão r = 4 é:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em uma progressão aritmética (a<sub>1</sub>, a<sub>2</sub>, ..., a<sub>n</sub> ...),&nbsp;tem-se a<sub>2</sub> = 3 e a<sub>8</sub> = 18.&nbsp;Qual é o valor de <sup>a</sup><sub>33</sub>?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Seja a progressão de números (32, 80, 128, 176,....). Qual o valor da soma dos 100 primeiros números dessa progressão?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em uma Progressão Aritmética, o décimo termo vale <strong>16 </strong>e o nono termo é <strong>6</strong> unidades maior do que o quinto termo.</p> <p>&nbsp;</p> <p>Logo, o décimo segundo termo vale:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Na propaganda de um curso de leitura dinâmica divulgado nas redes sociais, observou-se que houve 20 visualizações no primeiro dia. No segundo dia foram 37 visualizações, no terceiro dia 54, no quarto 71 e assim sucessivamente nos dias seguintes da propaganda.</p> <p>&nbsp;</p> <p>Qual é o número de visualizações que deve ocorrer no 17º dia de divulgação da propaganda se essa proporção continuar nos mesmos parâmetros?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Assinale a única alternativa correta, para a PA de quatro termos, em que o 1º termo é a <sub>1</sub> = -6 e a razão é r = 8.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>A PG é toda sequência de números não nulos na qual é constante o quociente da divisão de cada termo “a partir do segundo” pelo termo anterior. Esse quociente constante é chamado de razão da progressão. Assinale a única alternativa correta, após determinar a razão de (2, 8,...)&nbsp;</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Observe a figura dada abaixo na qual foi construida usando palitos de fósforos inteiros. Com os palitos é possível construir a seguinte sucessão de figuras compostas por triângulos.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Uma determinada colônia de bactérias possui, em um determinado instante, 20.000 organismos. Sabendo que essa população dobra a cada 12 horas, quantos organismos haverá depois de decorridos 3 dias?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Determine x para que a sequência forme uma PG. (x–1, x, x+5):</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>O 6º termo da sequência 2, 8, 32, 128, ... é um número cuja soma dos algarismos é&nbsp;</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Seja a PG (a<sub>1</sub>, a<sub>2</sub>, a<sub>3</sub>, a<sub>4</sub>, ...) de razão q = 2. Se a<sub>1</sub> + a<sub>5</sub> = 272, o valor de a<sub>1</sub> é&nbsp;</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em um grupo de 10 crianças, certo número de bombons foi distribuído para cada uma, em uma progressão aritmética crescente, da criança de menor estatura para a de maior estatura. Se colocarmos as crianças nessa ordem, perceberemos que a terceira criança ganhou 7 bombons e a oitava ganhou 17. Quantos bombons foram distribuídos?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Determine o <strong>2017º </strong>termo da Progressão Aritmética cujo<strong> 1º</strong> termo é<strong> 4</strong> e cuja razão é <strong>2</strong>.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>No dia 7 de abril (Dia Mundial da Saúde) de 2017 – a Organização Mundial da Saúde (OMS) deu início a uma campanha sobre depressão com o lema “Vamos Conversar”. A iniciativa reforça que existem formas de prevenir a depressão e também de tratá-la. Suponha que duas mil pessoas aderiram no primeiro dia, quatro mil, no segundo dia; seis mil, no terceiro dia e assim sucessivamente. Seguindo essa razão, quantas pessoas, no total, serão atingidas na campanha do primeiro ao vigésimo dia?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>A soma dos 101 primeiros números ímpares positivos é:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em uma P.A., o 72° termo vale 672 e o primeiro vale 33. Dessa forma, a razão dessa P.A. é:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em uma empresa o funcionário mais velho tem 62 anos e o mais novo 20 anos. Ordenando as idades dos funcionários, do mais novo para o mais velho, obtemos uma progressão aritmética de razão 3. Nessa empresa, o número de funcionários com mais de 40 anos é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em uma Progressão Aritmética , em que o 1º termo é 23 e a razão é -6 , a posição ocupada pelo termo -13 é :</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>&nbsp; &nbsp; A figura ilustra uma sequência de formas geométricas formadas por palitos, segundo uma certa regra.</p> <p><img height="75" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_c1585bf1b6c74c8b3e8c3fa56822fff6_1804287.jpg.png" style="display:block;margin-left:auto;margin-right:auto;" width="467"></p> <p>Continuando a sequência, segundo essa mesma regra, quantos palitos serão necessários para construir o décimo termo da sequência?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>A razão da P.A., cujo termo geral de ordem <em>n</em> é <em>a<sub>n</sub></em> = 3<em>n</em> - 8,&nbsp;com <em>n</em>&nbsp;inteiro positivo não nulo, é:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Um fisioterapeuta elaborou o seguinte plano de treinos diários para o condicionamento de um maratonista que se recupera de uma contusão:<br><br>• primeiro dia -corrida de 6 km;<br><br>• dias subsequentes -acréscimo de 2 km à corrida de cada dia imediatamente anterior.<br><br>O último dia de treino será aquele em que o atleta correr 42 km.<br><br>O total percorrido pelo atleta nesse treinamento, do primeiro ao último dia, em quilômetros, corresponde a:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Observe bem as três figuras que são mostradas abaixo. Todas elas são formadas por quadrinhos de mesmo tamanho.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em virtude da grande crise que está afetando o Brasil durante os dois últimos anos, com um reflexo muito grande no desemprego (mais de 13 milhões de pessoas sem emprego, dados do próprio governo), uma empresa em processo de restauração, para se manter em atividade, propôs a seus funcionários uma indenização financeira para os que pedissem demissão, que variava em função do número de anos trabalhados. A tabela abaixo será utilizada para calcular o valor (i) da indenização, em função do tempo trabalhado (t).</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em uma progressão aritmética (P.A.), a soma dos três primeiros termos é igual a 117. Sabendo que o primeiro termo é 30, a razão dessa P.A. é</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Um atleta de natação treina, habitualmente, cinco vezes por semana em uma piscina de 50 metros de comprimento de um clube. Com o objetivo de melhorar seu condicionamento físico, ele decide iniciar seu treino na segunda-feira nadando 4800 metros, nadando mais a cada dia da semana, em progressão aritmética. A tabela a seguir mostra as distâncias que ele nadou na segunda-feira e na quinta-feira de uma determinada semana.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Se x é um número real positivo, então o valor de x, que torna a sequência&nbsp;<img src="https://img.estuda.com/temp/formula_329b92944217f4ab7033ebc1ba1fd496.png?zdn">&nbsp;uma progressão geométrica, é</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Determine o 10º termo de uma progressão aritmética, sabendo que o primeiro termo é 2017 e a razão é 7.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Sabendo que o primeiro termo de uma Progressão Geométrica é a<sub>1</sub> = 2 e a razão q = 3, determine a soma dos 5 primeiros termos dessa progressão:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Ao saber que a esposa estava grávida, um homem passa a armazenar latas de leite no quarto do bebê, aguardando sua chegada, porém, para ficar bem decorado, ele as junta formando uma pirâmide, onde na fila superior tem uma lata, na segunda fila duas latas, na terceira três e assim por diante até a fila da base. Se ele consegue formar exatamente 10 filas sem sobras de latas, quantas latas ele conseguiu juntar?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Um usuário do Facebook, embalado pela polêmica envolvendo a vaquejada, expõe sua opinião sobre o tema nessa rede social. Acompanhando os compartilhamentos de sua postagem, ele percebe que a quantidade de compartilhamentos a cada hora forma uma progressão geométrica de razão 𝒒 = 𝟑 e primeiro termo 𝒂<sub>𝟏</sub> = 𝟑. Considerando essas informações, a quantidade de compartilhamentos, na quinta hora, foi de</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>As corridas com obstáculos são provas de atletismo que fazem parte do programa olímpico e consistem em corridas que têm no percurso barreiras que os atletas têm de saltar. Suponha que uma prova tenha um percurso de 1000 metros e que a primeira barreira esteja a 25 metros da largada, a segunda a 50 metros, e assim sucessivamente.<br>\nSe a última barreira está a 25 metros da linha de chegada, o total de barreiras no percurso é</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Encontre o primeiro termo de uma progressão geométrica decrescente e ilimitada, de razão igual a&nbsp;<img src="https://img.estuda.com/temp/formula_93b05c90d14a117ba52da1d743a43ab1.png?zdn">,&nbsp;sabendo que o limite da soma dos seus termos é igual a 16.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Na ordem apresentada, os números a seguir formam uma progressão aritmética.</p> <p><img height="44" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_7c4d97317266aed49bba850aefa5a630_992758.jpg.png" width="216"></p> <p>Deste modo, o próximo número dessa progressão será</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em uma Progressão Aritmética com <strong>6</strong> termos, temos que a soma de seus termos é igual a <strong>102 </strong>e seu último termo é <strong>27</strong>.</p> <p>&nbsp;</p> <p>Com base nessas informações, a razão dessa progressão é:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em uma progressão aritmética cujo primeiro termo é 1,87 e a razão é 0,004, temos que a soma dos seus dez primeiros é igual a:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Na P.A. (2, 4, 6, 8, 10, …), quem será o a<sub>10</sub>?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>De modo a formar uma progressão aritmética de razão dois, Pedro escolhe para senha, uma combinação de cinco números inteiros positivos menores que dez (<em>n</em><sub>1</sub>,&nbsp;<em>n</em><sub>2</sub>,&nbsp;<em>n</em><sub>3</sub>,&nbsp;<em>n</em><sub>4</sub>,&nbsp;<em>n</em><sub>5</sub>), cuja soma dos termos equivale a 25.</p> <p>&nbsp;</p> <p>Qual o valor de <em>n</em><sub>3</sub>?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Para comemorar o aniversário de uma cidade, a prefeitura organiza quatro dias consecutivos de atrações culturais. A experiência de anos anteriores mostra que, de um dia para o outro, o número de visitantes no evento é triplicado. É esperada a presença de 345 visitantes para o primeiro dia do evento.</p>\n<p>Uma representação possível do número esperado de participantes para o último dia é</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>&nbsp; Um parque temático expõe dois aquários, com 50 espécies de peixes diferentes, conforme descrito a seguir.&nbsp;</p> <p>&nbsp;</p> <p>•&nbsp;No primeiro (de água doce), há <em>a<sub>i</sub> </em>exemplares da<em> i</em>-ésima espécie, com <em>i</em> = 1, 2, ..., 10; a sequência (<em>a<sub>1</sub>, <strong>···</strong>, a<sub>10</sub></em>) está em progressão geométrica;<em> a<sub>1</sub></em> = 2 e <em>a<sub>3</sub></em> = 18.&nbsp;<br>\n•&nbsp;No segundo aquário (de água salgada), há<em> b<sub>j</sub></em> exemplares da <sub>j</sub>-ésima espécie, com<em> j</em> = 1, 2, ..., 40; a sequência (<em>b<sub>1</sub>, <strong>···</strong>, b<sub>40</sub></em>) está em progressão aritmética;<em> b<sub>4</sub></em> = 70 e<em> b<sub>30</sub></em> = 668.&nbsp;</p> <p>&nbsp;</p> <p>Tendo como referência essas informações, julgue o<strong>&nbsp;</strong>item.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Observe a sequência a seguir:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>O número de termos da&nbsp;<img class="formula" src="sis_questoes/formulas/071865eb371409ccc5a03582f0cb5035.png?latex=P.G.%5Cleft(%5Cfrac%7B1%7D%7B9%7D%2C%5Cfrac%7B1%7D%7B3%7D%2C1...729%5Cright)" border="0">&nbsp;é:&nbsp;</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Um funcionário alinhou 55 medalhas em cima da mesa, de modo que imediatamente após uma medalha de ouro havia uma de prata, imediatamente após uma de prata havia uma de bronze e imediatamente após uma medalha de bronze havia uma de ouro, e assim sucessivamente.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>João comprou um presente para sua esposa Maria e parcelou a compra da seguinte maneira: a primeira parcela foi de R$50,00, a segunda de R$52,00, a terceira de R$54,00 e assim sucessivamente até a última parcela de R$100,00. O valor total do presente é:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Considere que o número de países que passaram a participar dos Jogos Olímpicos em um dado período de tempo obedeça à seguinte seqüência (11, a, 29, b, 47), que é uma progressão aritmética, então a soma a + b é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em uma apresentação circense, forma-se uma pirâmide humana com uma pessoa no topo sustentada por duas outras que são sustentadas por mais três e assim sucessivamente. Quantas pessoas são necessárias para formar uma pirâmide com oito filas de pessoas, da base ao topo?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>O sítio de um dos voluntários que auxiliou os moradores do desastre fica a 5,5 km do local. Ele fez várias viajens de ida e volta durante os cinco dias em que ajudou nos resgates. No primeiro dia, ele foi ao local uma vez; no segundo dia, ele foi duas vezes; no terceiro, três vezes e, assim, sucessivamente. É correto afirmar que, nesse período, ele percorreu um total de</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Conforme a Agência da ONU para os Refugiados (ACNUR), temos testemunhado o aumento do deslocamento forçado de pessoas em todo o mundo, ocasionado por guerras e conflitos. Em 2014, segundo esta agência, estes deslocamentos afetavam 59,5 milhões de pessoas. Se o número de deslocamentos forçados crescer anualmente, segundo uma progressão geométrica de razão 1,14, então, em 2015 esse número será de</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Desejando incentivar a permanência da sua família no campo, onde pretendia instalar um hotel-fazenda para a terceira idade, um fazendeiro distribuiu os 90,0 hectares de uma de suas fazendas, pelos três filhos, de modo que os lotes estivessem em progressão aritmética, e ao mais novo coubessem oito sétimos do lote do mais velho.</p> <p>Nessas condições, o menor dos lotes, em hectares, compreendia</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Num painel eletrônico acendeu 2 lâmpadas, no primeiro segundo, no segundo acendeu 4 lâmpadas e no terceiro mais 6 lâmpadas e assim por diante. Após 50 segundos o painel ficou totalmente aceso. A quantidade total de lâmpadas do painel é igual a:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Numa Progressão Geométrica, a<sub>1</sub> = 3 e a<sub>3</sub> = 12 , a soma dos oito primeiros termos positivos é:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Quatro números estão dispostos de forma tal que constituem uma PG finita. O terceiro termo é igual a 50 e a razão é igual a 5. Desta maneira, o produto de a<sub>1</sub>.a<sub>4</sub> vale</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>A progressão aritmética, cuja fórmula do termo geral é dada por a<sub>n</sub> = 5n - 18 , tem razão igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Admita que a sequência&nbsp;<img src="https://img.estuda.com/temp/formula_e8609b78f5f3d841f7cca46d0fbdfe97.png?zdn">&nbsp;seja uma progressão aritmética.<br>\nO valor de t é igual a:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Calculando a soma dos termos da P.G. (7, 14, 28, ..., 3584).</p> <p>&nbsp;</p> <p>Temos como solução:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Um professor de Matemática do Curso de Licenciatura do IFRR escreveu a seguinte tarefa para os alunos resolverem: “<em>Uma progressão aritmética e uma progressão geométrica têm, ambas, o primeiro termo igual a 4, sendo que os seus terceiros termos são estritamente positivos e coincidem. Sabe-se ainda que o segundo termo da progressão aritmética excede o segundo termo da progressão geométrica em 2. Qual o terceiro termo das progressões</em>?”.</p> <p>&nbsp;</p> <p>Marque a resposta encontrada pelos alunos:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Quatro números estão em PA de razão 3.</p> <p>&nbsp;</p> <p>Se o primeiro termo somado ao último é igual a 19, então o primeiro termo é</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': 'A taxa de um determinado condomínio da cidade de Fortaleza é paga de acordo com o andar em que se mora. Quem mora no 1° andar paga R$ 105,00; no 2° andar paga R$ 120,00. Sabendo que os valores a serem pagos estão em progressão aritmética, quanto pagará, em reais, quem mora no décimo andar desse condomínio?<br>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': 'Se (<em>a</em><sub>1</sub>, <em>a</em><sub>2</sub>, … , <em>a</em><sub>13</sub> ) é uma progressão aritmética (PA) cuja soma dos termos é 78, então <em>a</em><sub>7</sub> é igual a<br>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Considere a seguinte sequência: 1, 1, 2, 4, X. Obtenha o valor de X.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>A “Chikungunya”, como a dengue e outras viroses, é uma doença que preocupa a população de modo geral. Admita-se, hipoteticamente, que, em janeiro de 2014, houve 37 casos de uma determinada doença, em fevereiro, 55 novos casos ocorreram, e assim por diante, com o número de novos casos aumentando a cada mês, como uma progressão aritmética.</p>\n<p>&nbsp;</p>\n<p>Continuando assim, o total de casos, ao longo desse ano, será</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Uma pessoa obesa, pesando num certo momento 130 kg, recorre a uma dieta “milagrosa”, que promete perda de até 2,5 kg por semana. Suponhamos que essa pessoa perca realmente 2,5 kg por semana.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Com a popularização das redes sociais, para um vídeo tornar-se notável ou “viral” em poucas horas, bastam alguns milhares de compartilhamentos. Supondo que um vídeo tenha sido lançado na internet, e na primeira hora tenha 3.000 compartilhamentos, em 3 horas 12.000, e em 5 horas 48.000 compartilhamentos, em 10 horas o número de compartilhamentos será de</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p><strong>TEXTO</strong></p> <p>&nbsp;</p> <p>O envio e o recebimento de informações sigilosas é uma necessidade antiga, que existe há centenas de anos. Com o surgimento da internet e sua consequente facilidade de transmitir dados de maneira precisa e extremamente rápida, a criptografia tornou-se uma ferramenta fundamental para permitir que apenas o emissor e o receptor tenham acesso livre à informação trabalhada. O termo criptografia surgiu da fusão das palavras gregas “kryptós” e “gráphein”, que significam “oculto” e “ escrever”, respectivamente. O sistema mais utilizado é o de chave de bit. Quanto mais bits forem utilizados, mais segura é a criptografia.</p> <p><small>Disponível em: http://www.infowester.com/criptografia.php. Acessado em: 03 de abril de 2015.</small></p> <p>&nbsp;</p> <p>Uma das técnicas utilizadas é a decodificação com a chave simétrica.</p> <p><img height="320" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_c7866dba3f86fd35ac53f759e01df733_c19fea24e1902aed235ab9f251728ba0.png" width="545"></p> <p>Caso um algoritmo use chave de 4 bits, por exemplo, apenas 16 chaves poderão ser utilizadas na decodificação. Caso use 5 bits, 32 chaves poderão ser utilizadas na decodificação e, caso use 6 bits, 64 chaves na decodificação. De acordo com estas informações, se utilizarmos 8 bits, quantas chaves poderão ser utilizadas na decodificação?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em um treinamento de condicionamento físico, um soldado inicia seu primeiro dia correndo 800 m. No diaseguinte corre 850 m. No terceiro 900 m e assim sucessivamente até atingir a meta diária de 2.200 m.</p> <p>&nbsp;</p> <p>Ao final de quantos dias, ele terá alcançado a meta?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': 'As prestações de um financiamento imobiliário constituem uma progressão aritmética na ordem em que são pagas. Sabendo que a 15ª prestação é R$ 3 690,00 e a 81ª prestação é R$ 2 700,00, o valor da 1ª prestação é<br>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Admita a realização de um campeonato de futebol no qual as advertências recebidas pelos atletas são representadas apenas por cartões amarelos.Esses cartões são convertidos em multas, de acordo com os seguintes critérios: <br><br>• os dois primeiros cartões recebidos não geram multas; <br><br>• o terceiro cartão gera multa de R$ 500,00; <br><br>• os cartões seguintes geram multas cujos valores são sempre acrescidos de R$ 500,00 em relação ao valor da multa anterior.&nbsp;<br><br>Na tabela, indicam-se as multas relacionadas aos cinco primeiros cartões aplicados a um atleta.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': 'Considere uma progressão geométrica cujo primeiro termo seja 3 e sua razão, <img src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_7292df156bc6d8af23bff218ddf248ea_26in.png" alt="">&nbsp;, Obtenha a soma de seus infinitos termos.<br>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Um ciclista participará de uma competição e treinará alguns dias da seguinte maneira: no primeiro dia, pedalará 60 km; no segundo dia, a mesma distância do primeiro mais r km; no terceiro dia, a mesma distância do segundo mais r km; e, assim, sucessivamente, sempre pedalando a mesma distância do dia anterior mais r km. No último dia, ele deverá percorrer 180 km, completando o treinamento com um total de 1 560 km.<br>\n<br>\nA distância r que o ciclista deverá pedalar a mais a cada dia, em km, é</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p><strong>O primeiro termo de uma progressão geométrica é 4 e a razão é 5. Qual é o quarto termo dessa progressão geométrica?&nbsp;</strong></p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Na semana Farroupilha, geralmente, cavaleiros se reúnem para uma cavalgada e percorrem certo trajeto combinado previamente. Supondo que um grupo de cavaleiros percorra cada dia 2,5 km a menos do que percorreu no dia anterior e chegue ao seu destino em exatos sete dias, percorrendo 32 km no primeiro dia, o total do trajeto em quilômetros será de</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p><strong>TEXTO</strong></p> <p>&nbsp;</p> <p><strong>Geração digital: riscos das novas tecnologias para crianças e adolescentes</strong></p> <p><small>Evelyn Eisenstein<sup>1</sup> </small></p> <p><small>Susana B. Estefenon<sup>2</sup></small></p> <p>&nbsp;</p> <p>Se pudéssemos definir qual a geração digital, provavelmente, teríamos de considerar os adultos jovens que hoje têm 25 anos, quase a idade da internet. Muitos jogos de videogames que faziam sucesso naquela época, como o Super Mario Bros produzido pela Nintendo, são ainda hoje a porta de entrada para as crianças na longa teia da rede mundial de computadores. A primeira mensagem SMS foi enviada em 1992, os sites começaram a surgir em 1995 e o programa de correio eletrônico Hotmail apareceu em 1998, quando essas crianças ainda estavam no ensino médio. Em poucos anos, uma revolução, nem tão silenciosa, foi invadindo todas as casas e universidades e muitas escolas, inclusive públicas. Os primeiros sistemas de redes sociais, como o Orkut, apareceram em 2002 e o Skype, sistema de comunicação, é de 2003. O Youtube, que exibe filmes e vídeos, surgiu em 2005 e marcou o momento em que aqueles jovens estavam entrando para a universidade.</p> <p>&nbsp;</p> <p>Esses jovens cresceram num universo paralelo ao dos pais e ao de muitos de seus professores. Foram construindo novos conceitos, mudando comportamentos [...] Os adolescentes de hoje fotografam tudo com seus sofisticados celulares, têm acesso a todas as informações nos seus computadores e sabem de tudo em tempo real. São ágeis, curiosos, informados e dominam a tecnologia. Mesmo assim, existe a queda do rendimento escolar, as dificuldades do diálogo, um paradoxal isolamento no meio da rede de tantos contatos e conexões e a falta de comunicação e do afeto nas famílias em que todos ficam "perdidos". “Com-viver” num mundo em constante e cada vez mais veloz transformação pode ocasionar riscos e problemas à saúde, durante uma fase de crescimento e desenvolvimento na qual talvez a maturação cerebral seja estimulada por tantas imagens coloridas em pixels que formam confusões e também problemas de memória e de concentração.</p> <p>&nbsp;</p> <p>Está se tornando frequente uma nova síndrome denominada de tecnoestresse. Ela se caracteriza pelo desejo incontrolável de verificar constantemente o correio eletrônico ou os programas de mensagens instantâneas como o MSN; de estar sempre atento ao toque do celular ou de brincar no computador ou dedilhar no celular em todos os momentos livres e, muitas vezes, ao mesmo tempo, nas multitarefas, induzindo a quadros de ansiedade generalizada.</p> <p>&nbsp;</p> <p>Quanto ao corpo, os riscos à saúde produzidos por horas e horas diante do computador não são poucos. Podem ocorrer: fadiga ocular e ressecamento da conjuntiva (síndrome do olho seco), conjuntivites, infecções de córnea e dores de cabeça; Síndrome do Túnel do Carpo e Lesões do Esforço Repetitivo (LER); transtornos do sono com alterações significativas do humor, irritabilidade, redução da capacidade intelectual e produtiva e dificuldade de atenção; Perda Auditiva Induzida pelo Ruído (PAIR); obesidade abdominal; transtornos posturais, sensação de dormência no pescoço, braço e mão, e as tenossinovites; uso de drogas e medicamentos oferecidos por meio de compras realizadas pelo computador; uso de drogas digitais, músicas e sons capazes de provocar sensações sensoriais ou efeitos mentais psicodélicos, inclusive crises convulsivas por estímulo luminoso do monitor ou epilepsia fotossensível, produzidos por ruídos e imagens estranhas em programas selecionados.</p> <p>&nbsp;</p> <p>Mas, o mais preocupante são as redes de pornografia, de pedofilia e de exploração sexual digital, com aliciamento de crianças e adolescentes e a produção de material com cenas de sexo explícito envolvendo menores de 18 anos. [...] Infelizmente, crianças e adolescentes não são apenas vítimas, mas também têm figurado como algozes, com mais frequência, numa lista ...
# {'content': '<p>Magno comprou um veículo, dando R$ 10.000,00 de entrada e o restante em 30 parcelas decrescentes que formavam uma Progressão Aritmética (PA). O valor da primeira parcela foi de R$ 1.000,00, a segunda parcela foi de R$ 970,00, a terceira parcela foi de R$ 940,00 e, assim, sucessivamente. O valor pago na última parcela foi de:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Interpolando-se 17 meios aritméticos entre 117 e 333, a razão da P.A. obtida e o seu 10º termo, serão, respectivamente.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': 'As medições da elevação do nível dos mares e oceanos feitas&nbsp;por mareógrafos ao longo da costa, no período de 1880&nbsp;a 2000, mostram que o nível global destes subiu a uma taxa&nbsp;média de 1,7 cm por década. Já as medições realizadas por&nbsp;altímetros-radares a bordo de satélites de sensoriamento remoto,&nbsp;para o período de 1990 a 2000, indicam que o nível&nbsp;subiu a uma taxa média de 3,1 cm por década.<br>\n<br>Admitindo que as condições climáticas que provocam esta elevação&nbsp;não se alterem nos próximos 50 anos, o nível global dos&nbsp;mares e oceanos deverá subir nesse período, em cm, entre<br>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Laura caminha pelo menos 5 km por dia. Rita também caminha todos os dias, e a soma das distâncias diárias percorridas por Laura e Rita em suas caminhadas não ultrapassa 12 km.</p> <p>&nbsp;</p> <p>A distância máxima diária percorrida por Rita, em quilômetros, é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Complete a frase corretamente: A sequência (2, 4, 8, ...)...</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>As projeções para a produção de arroz no período de 2012 - 2021, em uma determinada região produtora, apontam para uma perspectiva de crescimento constante da produção anual. O quadro apresenta a quantidade de arroz, em toneladas, que será produzida nos primeiros anos desse período, de acordo com essa projeção.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Um anfiteatro tem 12 fileiras de cadeiras. Na 1ª fileira há 10 lugares, na 2ª há 12, na 3ª há 14 e assim por diante (isto é, cada fileira, a partir da segunda, tem duas cadeiras a mais que a da frente).<br>\n<br>\nO número total de cadeiras é</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': 'Um casal tem três filhos cujas idades estão em progressão aritmétrica. Se a soma das idades desses filhos é 36 anos e se o filho mais velho tem 16 anos, marque a opção que indica a idade do filho mais novo do casal.<br>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Um técnico, utilizando um microscópio, constatou que cada célula de uma determinada bactéria se subdivide em três ao final de cada 15 minutos.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Suponha que o valor de um terreno atualmente seja de R$ 50.000,00. Sabendo que seu valor cresce linearmente com o tempo, de modo que daqui a 6 (seis) anos seu valor será R$ 80.000,00, é correto afirmar que daqui a 8 (oito) anos, contados a partir de hoje, o valor do terreno será:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em Manaus, o vício do cigarro atinge aproximadamente&nbsp;140 mil adultos, entre homens e mulheres. Contudo, o percentual de fumantes ativos vem diminuindo a cada ano. Suponha que o número de pessoas que abandonaram o vício em 2009, 2010 e 2011 forme, nessa ordem, uma PA crescente de razão 30. Se o número de pessoas que abandonaram o vício, somados esses três anos, foi 960, o número de pessoas que largaram o vício em 2011 foi</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em uma progressão aritmética, o primeiro termo é 5 e o décimo primeiro termo é 45.</p> <p>&nbsp;</p> <p>Pode-se afirmar que o sexto termo é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Jogar baralho é uma atividade que estimula o&nbsp;raciocínio. Um jogo tradicional é a Paciência, que utiliza&nbsp;52 cartas. Inicialmente são formadas sete colunas com as&nbsp;cartas. A primeira coluna tem uma carta, a segunda tem&nbsp;duas cartas, a terceira tem três cartas, a quarta tem quatro&nbsp;cartas, e assim sucessivamente até a sétima coluna, a&nbsp;qual tem sete cartas, e o que sobra forma o monte, que&nbsp;são as cartas não utilizadas nas colunas.<br>\n&nbsp;<br>\nA quantidade de cartas que forma o monte é</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': 'Em uma progressão aritmética de 14 termos, o primeiro termo vale 3 e o décimo‐quarto, 55. <br>A soma de todos os termos dessa progressão é igual a<br>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': 'Os valores das prestações mensais de certo financiamento constituem uma P.A. crescente de 12 termos. Sabendo que o valor da 1.ª prestação é R$ 500,00 e o da 12.ª é R$ 2.150,00, pode-se concluir que o valor da 10.ª prestação será igual a<br>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': 'Uma maneira muito útil de se criar belas figuras decorativas utilizando a matemática é pelo processo de autossemelhança, uma forma de se criar fractais. Informalmente, dizemos que uma figura é autossemelhante se partes dessa figura são semelhantes à figura vista como um todo. Um exemplo clássico é o <em>Carpete de Sierpinski</em>, criado por um processo recursivo, descrito a seguir:<br><br>• Passo 1: Considere um quadrado dividido em nove quadrados idênticos (Figura 1). Inicia-se o processo removendo o quadrado central, restando 8 quadrados pretos (Figura 2). <br>• Passo 2: Repete-se o processo com cada um dos quadrados restantes, ou seja, divide-se cada um deles em 9 quadrados idênticos e remove-se o quadrado central de cada um, restando apenas os quadrados pretos (Figura 3).<br>• Passo 3: Repete-se o passo 2.&nbsp;<br>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': 'O número mensal de passagens de uma determinada&nbsp;empresa aérea aumentou no ano passado nas seguintes&nbsp;condições: em janeiro foram vendidas 33 000 passagens;&nbsp;em fevereiro, 34 500; em março, 36 000. Esse padrão de&nbsp;crescimento se mantém para os meses subsequentes.<br>\n&nbsp;<br>\nQuantas passagens foram vendidas por essa empresa em julho do ano passado?<br>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Instrução: O texto refere-se à&nbsp;questão.</p> <p>&nbsp;</p> <p><em>&nbsp;&nbsp;Biojoias (ou ecojoias) são artigos de joalheria que misturam gemas e metais preciosos com material orgânico, como madeira, fibras de arumã ou casca de pupunheira, e são produzidas de forma exclusivamente artesanal. No Pará, o Polo Joalheiro São José Liberto, mantido pelo governo estadual desde 2002, treina ourives e designers na criação de peças que valorizem a cultura amazônica e o ambiente. </em></p> <p><small>(O Estado de S.Paulo, 24.11.2010.)</small></p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Um funcionário da Biblioteca Central deseja distribuir 200 livros nas prateleiras de acordo com o seguinte critério: na primeira prateleira, colocará 11 livros; na segunda prateleira, 13; na terceira, 15; e assim sucessivamente, até distribuir todos os livros em <strong>x</strong> prateleiras.</p> <p>&nbsp;</p> <p>Então, o número total de prateleiras usadas nessa distribuição é</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Um atleta de maratona em seu treinamento&nbsp;percorre 17 km na primeira hora de treino, 15 km&nbsp;na segunda hora, e assim por diante em progressão aritmética.<br>\nSe o atleta pretende percorrer em seu treino 100 km, quanto tempo gastará?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Para a confecção de uma árvore de Natal estilizada, utilizou-se uma prancha de madeira, em forma triangular, onde foram encaixadas lâmpadas enfileiradas conforme esquematizado na figura abaixo. A quantidade de lâmpadas utilizadas para a confecção desta árvore foi:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p><img height="119" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_base/1_46a95377f44c9caffae9676fec02ba52_6e2aaaffe6229490e01baf479ece6c5d.png" width="354"></p> <p>&nbsp;</p> <p>&nbsp; &nbsp; A sequência de figuras acima ilustra 3 passos da construção de um fractal utilizando-se como ponto de partida um triminó — nível I —, que consiste em uma peça formada por três quadradinhos de 1 cm de lado cada, justapostos em forma de L. No segundo passo, substitui-se cada quadradinho do fractal de nível I por um triminó, que tem os comprimentos dos lados de seus quadradinhos adequadamente ajustados à situação, de forma a se obter o fractal de nível II, conforme ilustrado acima. No terceiro passo, obtém-se, a partir do fractal de nível II, também substituindo-se cada um de seus quadradinhos por um triminó com os lados de seus quadradinhos ajustados, o fractal de nível III. O processo continua dessa forma, sucessiva e indefinidamente, obtendo-se os fractais de níveis n = I, II, III, ....</p> <p>&nbsp;</p> <p>Com base nessas informações, julgue o&nbsp;item&nbsp;que se segue.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p><img height="119" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_base/1_46a95377f44c9caffae9676fec02ba52_6e2aaaffe6229490e01baf479ece6c5d.png" width="354"></p> <p>&nbsp;</p> <p>&nbsp; &nbsp; A sequência de figuras acima ilustra 3 passos da construção de um fractal utilizando-se como ponto de partida um triminó — nível I —, que consiste em uma peça formada por três quadradinhos de 1 cm de lado cada, justapostos em forma de L. No segundo passo, substitui-se cada quadradinho do fractal de nível I por um triminó, que tem os comprimentos dos lados de seus quadradinhos adequadamente ajustados à situação, de forma a se obter o fractal de nível II, conforme ilustrado acima. No terceiro passo, obtém-se, a partir do fractal de nível II, também substituindo-se cada um de seus quadradinhos por um triminó com os lados de seus quadradinhos ajustados, o fractal de nível III. O processo continua dessa forma, sucessiva e indefinidamente, obtendo-se os fractais de níveis n = I, II, III, ....</p> <p>&nbsp;</p> <p>Com base nessas informações, julgue o&nbsp;item&nbsp;que se segue.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p><strong>Leonardo Fibonacci, também conhecido como Leonardo de Pisa, viveu entre os séculos XII e XIII, foi um matemático importante. Dentre outros trabalhos, criou uma sequência numérica que caracteriza uma série de fenômenos comuns na natureza, como o crescimento das folhas de árvores e as medidas dos ossos da mão humana. Tal sequência tem o número 1 como primeiro e segundo elementos. A partir do terceiro, cada elemento é a soma dos dois que o precedem. Assim, o décimo segundo elemento da sequência de Fibonacci é&nbsp;</strong></p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Observe a seqüência que segue:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Iferina resolveu fazer uma poupança para pagar os custos do seu casamento. Começou depositando R$ 100,00 no primeiro mês, R$ 130,00 no segundo, R$ 160,00 no terceiro, e assim por diante. Continuando nessa sequência de depósitos mensais, Iferina terá economizado após 10 meses</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Lisarb estava brincando de organizar bolinhas, como mostra a figura:</p> <p><img height="106" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_e063c2b7f7966ca0f076dfbf10ae5bf6_57f026d05892fa7b5795067df52f06c6.png" width="371"></p> <p>O número de bolinhas necessárias para fazer o próximo triângulo é</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': 'Dado uma PA cujo a<sub>1</sub> é o quádruplo de sua&nbsp;razão e a<sub>20</sub> é igual a 69, sua razão será:<br>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Devido à epidemia de gripe do último inverno, foram suspensos alguns concertos em lugares fechados. Uma alternativa foi realizar espetáculos em lugares abertos, como parques ou praças. Para uma apresentação, precisou-se compor uma platéia com oito filas, de tal forma que na primeira fila houvesse 10 cadeiras; na segunda, 14 cadeiras; na terceira, 18 cadeiras; e assim por diante.</p> <p>&nbsp;</p> <p>O total de cadeiras foi:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': 'Em uma caixa havia somente moedas de 50 centavos. Foram feitas sucessivas retiradas, sendo 5 moedas na 1.ª vez, 10 na 2.ª, 15 na 3.ª e assim sucessivamente, até não restar nenhuma moeda na caixa, o que ocorreu na 14.ª vez. O valor retirado da caixa na última vez foi de<br>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Nos últimos anos, a corrida de rua cresce no Brasil. Nunca se falou tanto no assunto como hoje, e a quantidade de adeptos aumenta progressivamente, afinal, correr traz inúmeros benefícios para a saúde física e mental, além de ser um esporte que não exige um alto investiment financeiro.</p> <p><small>Disponível em:http://www.webrun.com.br. Acesso em: 28 abr. 2010.</small></p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>O trabalho em empresas de festas exige dos profissionais conhecimentos de diferentes áreas. Na semana passada, todos os funcionários de uma dessas empresas estavam envolvidos na tarefa de determinar a quantidade de estrelas que seriam utilizadas na confecção de um painel de Natal. <br><br>Um dos funcionários apresentou um esboço das primeiras cinco linhas do painel, que terá, no total, 150 linhas.&nbsp;</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Uma revendedora de automóveis observou que, em determinado ano, a venda de veículos automáticos aumentava, mensalmente, segundo uma progressão aritmética de razão 50.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>As idades de três irmãos são os três primeiros elementos de uma progressão aritmética de razão 3 . Sabendo que a idade do mais velho é o triplo da idade do mais novo então a idade do “irmão do meio” é:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Foi publicada no site do clicrbs, no dia 28/07/2009, a reportagem “Epidemia deverá adiar volta às aulas em parte da rede escolar”, de onde foi retirado o fragmento abaixo:</p> <p>&nbsp; &nbsp; &nbsp; O titular da Saúde no Estado, Osmar Terra, estima que o número de pessoas infectadas pela nova gripe deverá saltar do atual patamar de 10 mil casos para aproximadamente 20 mil até a próxima segunda (03/08/2009), e dobrar novamente ao longo da semana seguinte, chegando a cerca de 40 mil gaúchos afetados devido à <strong>progressão geométrica</strong> [grifo nosso] dos contágios.<br>\n<small>Disponível em:http://www.clicrbs.com.br/especial/rs/dsm/19,0,2597285,Gripe-A-deve-retardar-reinicio-das-aulas-em-parte-da-rede-escolar.html</small></p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p><strong>A&nbsp;questão relaciona-se, de modo geral, a um ou mais dos subtemas escassez de alimentos, fome, miséria social.</strong></p> <p>&nbsp;</p> <p><strong>Leia os Textos I e II e responda a&nbsp;questão</strong></p> <p>&nbsp;</p> <p><strong>Texto I</strong><br>\n<em>Thomas Malthus (1766-1834) assegurava que, se a população não fosse de algum modo contida, dobraria de 25 em 25 anos, crescendo em progressão geométrica, ao passo que, dadas as condições médias da terra disponíveis em seu tempo, os meios de subsistência só poderiam aumentar, no máximo, em progressão aritmética.&nbsp;</em><br>\n&nbsp;</p> <p><strong>Texto II</strong><br>\n<em>A idéia de um mundo famélico assombra a humanidade desde que Thomas Malthus previu que no futuro não haveria comida em quantidade suficiente para todos.<br>\nOrganismos internacionais – Organização das Nações Unidas, Banco Mundial e Fundo Monetário Internacional – chamaram a atenção para a gravidade dos problemas decorrentes da alta dos alimentos. O Banco Mundial prevê que 100 milhões de pessoas poderão submergir na linha que separa a pobreza da miséria absoluta devido ao encarecimento da comida.</em></p> <p style="text-align: right;"><small>(Adaptado: FRANÇA, R. O fantasma de Malthus. Veja. 23 abr. 2008.)</small></p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Texto I</p> <p>Thomas Malthus (1766-1834) assegurava que, se a população não fosse de algum modo contida, dobraria de 25 em 25 anos, crescendo em progressão geométrica, ao passo que, dadas as condições médias da terra disponíveis em seu tempo, os meios de subsistência só poderiam aumentar, no máximo, em progressão aritmética.</p> <p>&nbsp;</p> <p>Texto II</p> <p>A idéia de um mundo famélico assombra a humanidade desde que Thomas Malthus previu que no futuro não haveria comida em quantidade suficiente para todos. Organismos internacionais – Organização das Nações Unidas, Banco Mundial e Fundo Monetário Internacional – chamaram a atenção para a gravidade dos problemas decorrentes da alta dos alimentos. O Banco Mundial prevê que 100 milhões de pessoas poderão submergir na linha que separa a pobreza da miséria absoluta devido ao encarecimento da comida.</p> <p><small>(Adaptado: FRANÇA, R. O fantasma de Malthus. Veja. 23 abr. 2008.)</small></p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Uma pessoa resolveu fazer sua caminhada matinal passando a&nbsp;percorrer, a cada dia, 100 metros mais do que no dia anterior.&nbsp;Ao completar o 21º dia de caminhada, observou ter percorrido,&nbsp;nesse dia, 6 000 metros. A distância total percorrida nos&nbsp;21 dias foi de:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>“A redução do Imposto sobre Produtos Industrializados (IPI) dos carros novos, promovida pelo governo federal, com o objetivo de amenizar os efeitos da crise financeira internacional no setor automotivo, resultou em uma queda na venda dos carros usados. A queda nas vendas dos carros populares, no estado do Rio Grande do Sul, é representada no gráfico abaixo.” <small>(Fonte: Site Notícias MG - adaptado)</small></p> <p>&nbsp;</p> <p><img height="287" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_efc1df43bacbe7be842d7e79e533c0c6_802753.jpg.png" width="422"></p> <p>&nbsp;</p> <p>Se as variações mensais no número de carros vendidos, apresentadas acima, formam uma progressão aritmética, o&nbsp;número de carros vendidos em abril será</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>O valor de <em>x</em> que satisfaz a equação&nbsp;<img src="https://img.estuda.com/temp/formula_6d063d98a0533da4b4f91c5c3699fdd1.png?zdn">, em que o primeiro membro é uma P.G. infinita, é</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Uma progressão aritmética tem razão <em>r</em> = -10, sabendo que seu 100º (centésimo) termo é zero, pode-se afirmar que seu 14º (décimo quarto) termo vale:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Um retângulo é o primeiro polígono de uma sequência. A partir desse termo, cada novo termo da sequência é formado pela adição de um retângulo semelhante ao retângulo adicionado no termo anterior, com lados indicando o dobro do tamanho, conforme a figura.</p> <p style="text-align: center;"><img height="70" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_d11f6f4aace3332e321034819bdcd4ec_3953198.jpg.png" width="335"></p> <p style="text-align: left;">O número de lados do polígono formado no 100° termo dessa sequência é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Se (<em>α</em><sub>1</sub>,&nbsp;<em>α</em><sub>2</sub>,&nbsp;<em>α</em><sub>3</sub>, ...)&nbsp;é uma progressão aritmética de razão 2 então podemos dizer que (2<sup><em>α</em><sub>1</sub></sup>,&nbsp;2<sup><em>α</em><sub>2</sub></sup>,&nbsp;2<sup><em>α</em><sub>3</sub></sup>, ...)&nbsp;é</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>As sequências a<sub>n</sub> e b<sub>n</sub> são duas progressões geométricas infinitas. Observe a representação dos primeiros termos de cada uma dessas sequências:</p> <p>&nbsp;</p> <p>a<sub>n</sub> = (x; 2x; 4x; 8x; 16x; ...)</p> <p>b<sub>n</sub>= (y; y/3; y/9; y/27; y/81; ...)</p> <p>&nbsp;</p> <p>Considere uma nova sequência cn, em que cada termo é obtido pelo produto entre os termos de mesma posição das sequências a<sub>n</sub> e b<sub>n</sub>, ou seja, c<sub>1</sub> = a<sub>1</sub> · b<sub>1</sub>, c<sub>2</sub> = a<sub>2</sub> · b<sub>2</sub>, c<sub>3</sub> = a<sub>3</sub> · b<sub>3</sub> e assim sucessivamente.</p> <p>&nbsp;</p> <p>A soma dos infinitos termos da sequência c<sub>n</sub> é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Seja S = (a<sub>1</sub> , a<sub>2</sub> , a<sub>3</sub> , ... , a<sub>n</sub>) uma sequência de números naturais em que:</p> <p>&nbsp;</p> <p>a<sub>1</sub> = 1</p> <p>a<sub>2 </sub>= 1</p> <p><img src="https://img.estuda.com/temp/formula_9379f26136cdcf742ae05c9a72156020.png?zdn">,&nbsp;para n &gt; 2</p> <p>&nbsp;</p> <p>A soma dos 50 primeiros termos dessa se - quência é igual a:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Sejam <em>f</em>:&nbsp;ℝ → ℝ e <em>g</em>: ℝ → ℝ definidas, respectivamente, por<em> f</em> (<em>x</em>) = 3<em>x</em> e <em>g</em>(<em>x</em>) = 3<sup><em>x</em></sup>. Então é CORRETO afirmar que a sequência (<em>g</em>(<em>f</em>(1)), <em>g</em>(<em>f</em>(2)),<em> g</em>(<em>f</em>(3)), ..., <em>g</em>(<em>f</em>(<em>n</em>)), ... )</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>&nbsp; O proprietário de um cinema está organizando as poltronas para um evento especial. Para atender a demanda desse evento, serão necessárias 540 poltronas.</p> <p>&nbsp;&nbsp;Em função da estrutura da apresentação do evento, foi solicitado que as poltronas fossem distribuídas da seguinte forma: 8 poltronas na primeira fila, 12 poltronas na segunda fila, 16 na terceira fila, e assim por diante.</p> <p>&nbsp;</p> <p>Com base nessas informações, é <strong>correto </strong>afirmar:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>&nbsp; O proprietário de um cinema está organizando as poltronas para um evento especial. Para atender a demanda desse evento, serão necessárias 540 poltronas.</p> <p>&nbsp;&nbsp;Em função da estrutura da apresentação do evento, foi solicitado que as poltronas fossem distribuídas da seguinte forma: 8 poltronas na primeira fila, 12 poltronas na segunda fila, 16 na terceira fila, e assim por diante.</p> <p>&nbsp;</p> <p>Com base nessas informações, é <strong>correto </strong>afirmar:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Considere as seguintes afirmações:</p> <p>&nbsp;</p> <p>I. se n é um número natural, então&nbsp;<img src="https://img.estuda.com/temp/formula_c876cb4a005ea9fcd5ed8800c1bf6492.png?zdn"></p> <p>II. se x é um número real e x<sup>3</sup> + x + 1 = 0, então&nbsp;<img src="https://img.estuda.com/temp/formula_444ab8ee6fb8c46af946d6bb384670a7.png?zdn"></p> <p>III. se <em>a</em>, <em>b </em>e <em>c </em>são números reais positivos que formam, nessa ordem, uma progressão aritmética, então&nbsp;<img src="https://img.estuda.com/temp/formula_82d02a0b22153fcea83aa417c27ab083.png?zdn">&nbsp;formam, nessa ordem, uma progressão aritmética.</p> <p>&nbsp;</p> <p>É(são) VERDADEIRA(S)</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Pensando em sua futura poupança, Roberto decidiu, no final de janeiro de 2018, investir no mercado de ações, adquirindo 100 ações da empresa VP. Seu plano foi, em cada um dos finais dos próximos 59 meses, comprar duas ações da mesma empresa a mais do que comprou no mês anterior.</p> <p>Logo após sua última compra, a ser feita no final de dezembro de 2022, seu investimento resultará em um total de N ações.</p> <p>&nbsp;</p> <p>Supondo que no período considerado não haja proventos que resultem em aumento no número de ações, pode-se afirmar que N é igual a:</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>&nbsp; &nbsp; Após o Fórum Nacional Contra a Pirataria (FNCP) incluir a linha de autopeças em campanha veiculada contra a falsificação, as agências fiscalizadoras divulgaram que os cinco principais produtos de autopeças falsificados são: rolamento, pastilha de freio, caixa de direção, catalisador e amortecedor.</p> <p style="text-align: right;"><small>Disponível em: www.oficinabrasil.com br. Acesso em: 25 ago. 2014 (adaptado).</small></p> <p>&nbsp;</p> <p>&nbsp; &nbsp; Após uma grande apreensão, as peças falsas foram cadastradas utilizando-se a codificação:&nbsp;</p> <p>&nbsp;</p> <p>&nbsp; &nbsp; 1: rolamento, 2: pastilha de freio, 3: caixa de direção, 4: catalisador e 5: amortecedor.</p> <p>&nbsp;</p> <p>&nbsp; &nbsp; Ao final obteve-se a sequência; 5, 4, 3, 2, 1, 2, 3, 4, 5, 4, 3, 2, 1, 2, 3, 4, 5, 4, 3, 2, 1, 2, 3, 4, ... que apresenta um padrão de formação que consiste na repetição de um bloco de números. Essa sequência descreve a ordem em que os produtos apreendidos foram cadastrados.</p> <p>&nbsp;</p> <p>O 2 015°&nbsp;item cadastrado foi um(a)</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Um artesão fabrica adereços de contas em forma de flores, colocadas lado a lado, onde cada flor tem um miolo escuro cercado por seis contas circulares claras.</p> <p style="text-align: center;"><img height="72" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_ba78f444d30f8bc1a890b6592110b3de_1307267.jpg.png" width="136"></p> <p style="text-align: left;">Sabendo-se que cada par de flores adjacentes tem duas pétalas em comum, como representado na figura, pode-se afirmar que utilizando 502 contas na confecção do adereço, ele será composto por um número máximo de flores igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Considere a sequência infinita <em><strong>IFALMIFALMIFALMIFALMIFALM</strong></em>….</p> <p>&nbsp;</p> <p>Qual é a<strong> 2019</strong>ª letra dessa sequência?</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Considerando a progressão geométrica (x<small>n</small>)<small>n&nbsp;= 1,2,3</small>,...., cujo primeiro termo é igual a sen(t) e a razão igual a cos<sup>2</sup>t, sendo 0 &lt; t &lt;&nbsp;𝜋/2, é correto afirmar que a soma (infinita) de todos os termos dessa progressão é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>&nbsp; &nbsp;&nbsp;Um casal de coelhos, considerado a primeira geração de uma família (<em>a</em><sub>1</sub> = 2), se reproduziu rapidamente. Na segunda geração, a família aumentou para 6 coelhos (<em>a</em><sub>2</sub> = 6); na terceira, para 12 (<em>a</em><sub>3</sub> = 12); na quarta, para 20 (<em>a</em><sub>4</sub> = 20); e assim sucessivamente.</p> <p>&nbsp;</p> <p>Nessas condições, se não houver mortes nessa família, haverá 30 e 42 coelhos na quinta e na sexta gerações respectivamente, porque a sequência</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Considerando a progressão aritmética&nbsp;<img src="https://img.estuda.com/temp/formula_db59dbe901d7f904a57815c89b4eb12a.png?zdn">&nbsp;cujo primeiro termo&nbsp;<img src="https://img.estuda.com/temp/formula_aa687da0086c1ea060a8838e24611319.png?zdn">&nbsp;é igual a&nbsp;<img src="https://img.estuda.com/temp/formula_7d0ab8fde227931c7e02de2f71305a20.png?zdn">&nbsp;e a razão é igual a&nbsp;<img src="https://img.estuda.com/temp/formula_4b1771a5479d6483a2e2ae8af2a172d6.png?zdn">&nbsp;pode-se definir, para cada inteiro positivo n, a soma&nbsp;<img src="https://img.estuda.com/temp/formula_7a8a9385f42d6256319465b451710324.png?zdn"></p> <p>&nbsp;</p> <p>Nessas condições,&nbsp;<img src="https://img.estuda.com/temp/formula_7c522b2865d075c0109e5574e6ddb8fa.png?zdn"> é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Considere a soma</p> <p>&nbsp;</p> <p><img src="https://img.estuda.com/temp/formula_6b5c22c3ec8b81c4f025d80b309f3c98.png?zdn"></p> <p>&nbsp;</p> <p>ou seja, a soma continua para <em>n</em>, crescendo indefinidamente.</p> <p>&nbsp;</p> <p>Assinale a opção que apresenta o valor de <em>S</em>.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Se&nbsp;<img src="https://img.estuda.com/temp/formula_6c448f8a2c2e2bef23cac3afa6ee2988.png?zdn">&nbsp;com <em>x, y, z&nbsp;</em>∈<em> N</em> e <em>x, y, z</em>&nbsp;estão em progressão geométrica nessa ordem, encontre o valor de y.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em 1991, uma determinada região do Estado teve 2800 casos de dengue. Campanhas de combate ao mosquito transmissor reduziram o número de casos, a cada ano, em uma progressão geométrica, chegando a 350 casos no ano 2000.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>Em 1991, uma determinada região do Estado teve 2800 casos de dengue. Campanhas de combate ao mosquito transmissor reduziram o número de casos, a cada ano, em uma progressão geométrica, chegando a 350 casos no ano 2000.</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# {'content': '<p>A soma de todos os números naturais ímpares até 2019, menos a soma de todos os números naturais pares até 2019, é igual a</p>', 'subjectName': 'matematica', 'tags': ['Álgebra', 'Sequências']}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-79bc50968c85> in <module>
#       1 for questao in questoes:
# ----> 2     if questao["tags"][1] == "Sequências":
#       3         print(questao)
#
# IndexError: list index out of range
