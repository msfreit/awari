# %%
# pip install pymongo
# pip install pymongo[srv]

from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient("mongodb+srv://revisapp-admin:f645HbS2AcypdWbG@cluster0.hmkez.mongodb.net/revisapp-mat?retryWrites=true&w=majority")
database = client["revisapp"]
collection = database["questions"]

# %%
query = {}

query["subjectName"] = u"matematica"
query["tags"] = u"\u00C1lgebra"
sort = [ (u"tags.0", -1) ]
cursor = collection.find(query, sort = sort)

# %%
cursor

# %%
try:
    for doc in cursor:
        print(doc)
finally:
    client.close()
# Out:
# {'_id': ObjectId('60b8f1433b844518e0e6ffde'), 'options': ['25', '50', '75', '150'], 'tags': ['Álgebra', 'Álgebra linear'], 'key': 'd_questao_1368122', 'name': 'Questão 17 1368122', 'testName': 'PUC-RS Verão 2020', 'content': '<p>Um padeiro acabou de receber de um fornecedor três sacos de farinha de diferentes tamanhos.</p> <p>&nbsp;</p> <p>Sabendo que o terceiro e o segundo sacos, juntos, têm 50 quilogramas, que o primeiro e o segundo, juntos, têm 45 quilogramas e que o primeiro e o terceiro, juntos, têm 55 quilogramas, a quantia total de farinha que acabou de receber, em quilogramas, foi</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 12, 3, 762000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 12, 3, 762000), '__v': 0}
# {'_id': ObjectId('60b8f14f3b844518e0e6ffe3'), 'options': ['R$ 0,45', 'R$ 0,40', 'R$ 0,38', 'R$ 0,35', 'R$ 0,30'], 'tags': ['Álgebra', 'Função Função Afim'], 'key': 'd_questao_1425146', 'name': 'Questão 8 1425146', 'testName': 'UNIFOR 2020', 'content': '<p>Uma pessoa pegou um táxi para ir ao trabalho. A distância de casa ao trabalho é de 12 km. Na ida, ela pagou R$ 29,10, na bandeira 1. Na volta para casa à noite, ela pegou um táxi novamente e pagou R$ 33,90, na bandeira 2, pelo mesmo trajeto.</p> <p>&nbsp;</p> <p>O acréscimo, por quilômetro rodado, da bandeira 1 para a bandeira 2 foi de</p>', 'level': 0, 'rightAnswer': 1, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 12, 15, 693000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 12, 15, 693000), '__v': 0}
# {'_id': ObjectId('60b8f15e3b844518e0e6ffe7'), 'options': ['10 dias.', '12 dias.', '13 dias.', '14 dias.', '15 dias.'], 'tags': ['Álgebra', 'Função Função Exponencial'], 'key': 'd_questao_1425169', 'name': 'Questão 12 1425169', 'testName': 'UNIFOR 2020', 'content': '<p>Em uma colônia de formigas, observou-se que, no instante t = 0, o número de formigas era de 1000 e que o crescimento desse formigueiro é dado pela função f definida por f(t) = 1000 . 2<sup>3t/5</sup>, onde t é o tempo decorrido em dias.</p> <p>&nbsp;</p> <p>Supondo que não haja morte de formigas nesse formigueiro, então, em quantos dias, no mínimo, esse formigueiro atingirá 64.000 formigas?</p>', 'level': 0, 'rightAnswer': 0, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 12, 30, 540000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 12, 30, 540000), '__v': 0}
# {'_id': ObjectId('60b8f15e3b844518e0e6ffea'), 'options': ['α<em> </em>= -1', 'α<em> </em>= - 1/2', 'α<em> </em>= 1/2', 'α<em> </em>= 1'], 'tags': ['Álgebra', 'Função'], 'key': 'd_questao_1440557', 'name': 'Questão 35 1440557', 'testName': 'UNICAMP 2020', 'content': '<p>Sabendo que α é um número real, considere a função <em>f</em>(<em>x</em>)<em> = </em>α<em>x</em> + 2,&nbsp;definida para todo número real <em>x</em>.&nbsp;</p> <p>&nbsp;</p> <p>Se <em>f</em>(<em>f</em>(1)) = 1, então</p>', 'level': 0, 'rightAnswer': 0, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 12, 30, 711000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 12, 30, 711000), '__v': 0}
# {'_id': ObjectId('60b8f15e3b844518e0e6ffeb'), 'options': ['30.', '10.', '- 15.', '- 20.'], 'tags': ['Álgebra', 'Sequências'], 'key': 'd_questao_1440578', 'name': 'Questão 37 1440578', 'testName': 'UNICAMP 2020', 'content': '<p>Considere que (<em>a, b</em>, 3,<em> c</em>)&nbsp;é uma progressão aritmética de números reais, e que a soma de seus elementos é igual a 8.</p> <p>&nbsp;</p> <p>O produto dos elementos dessa progressão é igual a</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 12, 30, 771000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 12, 30, 771000), '__v': 0}
# {'_id': ObjectId('60b8f15e3b844518e0e6ffec'), 'options': ['<img class="formula" src="https://img.estuda.com/temp/formula_671e1613eb3d042cf394ae20a0347e76.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_6e866535a5c668b35ab7aa4341504098.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_3fbaea99822614babf9da22b0a8cce27.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_5d6466ae40e99140e8d0cb32ab1cb42b.png?zdn">'], 'tags': ['Álgebra', 'Função Função Composta Função Exponencial'], 'key': 'd_questao_1440582', 'name': 'Questão 38 1440582', 'testName': 'UNICAMP 2020', 'content': '<p>Tendo em vista que <em>a</em> e <em>b</em>&nbsp;são números reais positivos,<em> </em><img src="https://img.estuda.com/temp/formula_239232d204bcd2d0dedfe0b330150509.png?zdn">&nbsp;considere a função&nbsp;<img src="https://img.estuda.com/temp/formula_300cec4cd5fe3f54e8791a44b3188d14.png?zdn">&nbsp;definida para todo número real <em>x</em>.</p> <p>&nbsp;</p> <p>Logo, <img src="https://img.estuda.com/temp/formula_804c00b3d22f9440a6e493617abf01fe.png?zdn">&nbsp;é igual a</p>', 'level': 0, 'rightAnswer': 0, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 12, 30, 817000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 12, 30, 817000), '__v': 0}
# {'_id': ObjectId('60b8f1693b844518e0e6ffef'), 'options': ['148', '124', '96', '88'], 'tags': ['Álgebra', 'Função'], 'key': 'd_questao_1515944', 'name': 'Questão 14 1515944', 'testName': 'CESUPA 2020', 'content': '<p>Uma espécie animal, cuja família inicial era de 288 elementos, foi testada em laboratório sob a ação de certa droga e constatado que a lei de sobrevivência entre tal família obedecia à relação:</p> <p>&nbsp;</p> <p>N(t) = a t<sup>2</sup> + b</p> <p>&nbsp;</p> <p>onde N(t) é igual ao número de elementos vivos no tempo t (dado em horas) e a e b parâmetros que dependiam da droga ministrada. Sabe-se que a família desapareceu (morreu o último elemento) quando t = 12h (após o inicio do experimento).</p> <p>&nbsp;</p> <p>Quantos elementos tinha esta família após 10h do início da experiência?</p>', 'level': 0, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 12, 41, 843000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 12, 41, 843000), '__v': 0}
# {'_id': ObjectId('60b8f1693b844518e0e6fff1'), 'options': ['2', '3', '4', '5', '7'], 'tags': ['Álgebra', 'Álgebra linear'], 'key': 'd_questao_1518172', 'name': 'Questão 43 1518172', 'testName': 'CESMAC 2° Dia Medicina 2020/1', 'content': '<p>Em uma clínica vascular, trabalham oito médicos. A cada dois anos, os médicos elegem um, dentre eles, para ser o diretor da clínica. A votação é aberta, e cada médico pode votar em até três pessoas, por voto direto. Enumerando os médicos de 1 a 8, a matriz a seguir representa a votação, onde a<sub>ij</sub> = 1 se o médico i votou no médico j, e a<sub>ij</sub> = 0, caso contrário:</p> <p style="text-align: center;"><img height="271" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_0882851d2509295e61e6ddcace33be00_1518172.jpg.png" width="282"></p> <p style="text-align: left;">Qual o número do médico que ganhou a eleição?</p>', 'level': 0, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 12, 41, 926000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 12, 41, 926000), '__v': 0}
# {'_id': ObjectId('60b8f1743b844518e0e6fff3'), 'options': ['0', '5/3', '1', '14/3', '8'], 'tags': ['Álgebra', 'Função Função Exponencial'], 'key': 'd_questao_1521838', 'name': 'Questão 21 1521838', 'testName': 'CESGRANRIO 2020', 'content': '<p>Considere as funções exponenciais g(x) = 2<sup>6x-10</sup> e h(x) = 8<sup>x-4</sup>, ambas de domínio real.</p> <p>&nbsp;</p> <p>Se g(2) = m e h(m) = k, qual é o valor de k?</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 12, 52, 435000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 12, 52, 435000), '__v': 0}
# {'_id': ObjectId('60b8f1833b844518e0e6fffd'), 'options': ['25/4', '5', '3/20', '15', '9/2'], 'tags': ['Álgebra', 'Sequências'], 'key': 'd_questao_1718459', 'name': 'Questão 12 1718459', 'testName': 'FAMEMA 2020', 'content': '<p>A progressão geométrica (a<sub>1</sub>, a<sub>2</sub>, a<sub>3</sub>, ...)&nbsp;tem primeiro termo a<sub>1</sub> = 3/8&nbsp;e razão 5.&nbsp; A progressão geométrica&nbsp;(b<sub>1</sub>, b<sub>2</sub>, b<sub>3</sub>, ...) tem razão 5/2.</p> <p>&nbsp;</p> <p>Se a<sub>5</sub> = b<sub>4</sub>,&nbsp;então b<sub>1&nbsp;</sub>é igual a</p>', 'level': 0, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 13, 7, 550000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 13, 7, 550000), '__v': 0}
# {'_id': ObjectId('60b8f1b93b844518e0e70018'), 'options': ['41', '43', '44', '45'], 'tags': ['Álgebra', 'Médias'], 'key': 'd_questao_3638551', 'name': 'Questão 69 3638551', 'testName': 'EEAR 2020/2', 'content': '<p>Há um conjunto de 5 valores numéricos, cuja média aritmética é igual a 40.</p> <p>&nbsp;</p> <p>Se for adicionado 5 ao primeiro desses valores e mantidos os demais, a nova média aritmética será</p>', 'level': 0, 'rightAnswer': 0, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 14, 1, 215000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 14, 1, 215000), '__v': 0}
# {'_id': ObjectId('60b8f1ce3b844518e0e70026'), 'options': ['X.', 'Y.', 'Z.', 'W.', 'T.'], 'tags': ['Álgebra', 'Médias'], 'key': 'd_questao_3649869', 'name': 'Questão 139 3649869', 'testName': 'ENEM 2° Dia 2020', 'content': '<p>&nbsp; &nbsp;&nbsp;Com o objetivo de contratar uma empresa responsável pelo serviço de atendimento ao público, os executivos de uma agência bancária realizaram uma pesquisa de satisfação envolvendo cinco empresas especializadas nesse segmento. Os procedimentos analisados (com pesos que medem sua importância para a agência) e as respectivas notas que cada empresa recebeu estão organizados no quadro.</p> <p style="text-align: center;"><img height="208" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_16803312bbe5fd4e3a2c45272218d69f_3649869.jpg.png" width="361"></p> <p style="text-align: left;">&nbsp; &nbsp;&nbsp;A agência bancária contratará a empresa com a maior média ponderada das notas obtidas nos procedimentos analisados.</p> <p style="text-align: left;">&nbsp;</p> <p style="text-align: left;">&nbsp; &nbsp; Após a análise dos resultados da pesquisa de satisfação, os executivos da agência bancária contrataram a empresa</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 14, 22, 747000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 14, 22, 747000), '__v': 0}
# {'_id': ObjectId('60b8f1e33b844518e0e70034'), 'options': ['<em>L</em>(<em>x</em>) = 50<em>x</em> – 1 200', '<em>L</em>(<em>x</em>) = 50<em>x</em> – 12 000', '<em>L</em>(<em>x</em>) = 50<em>x</em> + 12 000', '<em>L</em>(<em>x</em>) = 500<em>x</em> – 1 200', '<em>L</em>(<em>x</em>) = 1 200<em>x</em> – 500'], 'tags': ['Álgebra', 'Função'], 'key': 'd_questao_4142801', 'name': 'Questão 170 4142801', 'testName': 'ENEM Digital 2º Dia 2020', 'content': '<p>&nbsp; &nbsp; Por muitos anos, o Brasil tem figurado no cenário mundial entre os maiores produtores e exportadores de soja. Entre os anos de 2010 e 2014, houve uma forte tendência de aumento da produtividade, porém, um aspecto dificultou esse avanço: o alto custo do imposto ao produtor associado ao baixo preço de venda do produto. Em média, um produtor gastava R$ 1200,00 por hectare plantado, e vendia por R$ 50,00 cada saca de 60 kg. Ciente desses valores, um produtor pode, em certo ano, determinar uma relação do lucro<em> L</em> que obteve em função das sacas de 60 kg vendidas. Suponha que ele plantou 10 hectares de soja em sua propriedade, na qual colheu x sacas de 60 kg e todas as sacas foram vendidas.</p> <p style="text-align: right;"><small>Disponível em: www.cnpso.embrapa.br. Acesso em: 27 fev. 2012 (adaptado).</small></p> <p><br>\nQual é a expressão que determinou o lucro<em> L </em>em função de x obtido por esse produtor nesse ano?</p>', 'level': 0, 'rightAnswer': 1, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 14, 43, 698000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 14, 43, 698000), '__v': 0}
# {'_id': ObjectId('60b8f1ed3b844518e0e70036'), 'options': ['I.', 'II.', 'III.', 'IV.', 'V.'], 'tags': ['Álgebra', 'Função'], 'key': 'd_questao_4142854', 'name': 'Questão 172 4142854', 'testName': 'ENEM Digital 2º Dia 2020', 'content': '<p>&nbsp; &nbsp; Uma empresa de chocolates consultou o gerente de produção e verificou que existem cinco tipos diferentes de barras de chocolate que podem ser produzidas, com os seguintes preços no mercado:</p> <p><br>\n• Barra I: R$ 2,00;<br>\n• Barra II: R$ 3,50;<br>\n• Barra III: R$ 4,00;<br>\n• Barra IV: R$ 7,00;<br>\n• Barra V: R$ 8,00.</p> <p>&nbsp;<br>\n&nbsp; &nbsp; Analisando as tendências do mercado, que incluem a quantidade vendida e a procura pelos consumidores, o gerente de vendas da empresa verificou que o lucro <em>L</em> com a venda de barras de chocolate é expresso pela função <em>L</em>(<em>x</em>) = – <em>x</em><sup>2</sup> + 14<em>x</em> – 45, em que <em>x</em> representa o preço da barra de chocolate.<br>\n&nbsp; &nbsp; A empresa decide investir na fabricação da barra de chocolate cujo preço praticado no mercado renderá o maior lucro.</p> <p><br>\nNessas condições, a empresa deverá investir na produção da barra</p>', 'level': 0, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 14, 53, 998000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 14, 53, 998000), '__v': 0}
# {'_id': ObjectId('60b8f1f83b844518e0e7003c'), 'options': ['120.', '121.', '122.', '123.', '124.'], 'tags': ['Álgebra', 'Sequências'], 'key': 'd_questao_4154489', 'name': 'Questão 39 4154489', 'testName': 'UFRGS 4º Dia 2020', 'content': '<p>Considere o padrão de construção de triângulos com palitos, representado nas figuras abaixo.</p> <p style="text-align: center;"><img height="89" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_aee60ca5f7fa9b4638e44ac38489d88b_4154489.jpg.png" width="313"></p> <p style="text-align: left;">Na etapa n, serão utilizados 245 palitos. Nessas condições, n é igual a</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 15, 4, 107000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 15, 4, 107000), '__v': 0}
# {'_id': ObjectId('60b8f1f83b844518e0e70040'), 'options': ['6,0.', '7,0.', '8,0.', '9,0.', '9,5.'], 'tags': ['Álgebra', 'Médias'], 'key': 'd_questao_4154915', 'name': 'Questão 49 4154915', 'testName': 'UFRGS 4º Dia 2020', 'content': '<p>Após a aplicação de uma prova de Matemática, em uma turma de Ensino Médio com 30 estudantes, o professor organizou os resultados, conforme a tabela a seguir.</p> <p xxxxstyle="text-align: center;" xxxxxxxstyle="text-align: center;" xxxxxxxxstyle="text-align: center;"><img height="139" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_f9131361b6501c38721d13d81af0a3c1_4154915.jpg.png" style="display:block;margin-left:auto;margin-right:auto;" width="320"></p> <p style="text-align: left;">A nota mediana dessa prova de Matemática é</p> <p xxxxstyle="text-align: center;" xxxxxxxstyle="text-align: center;" xxxxxxxxstyle="text-align: center;"><img height="139" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_f9131361b6501c38721d13d81af0a3c1_4154915.jpg.png" width="320"></p>', 'level': 0, 'rightAnswer': 1, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 15, 4, 387000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 15, 4, 387000), '__v': 0}
# {'_id': ObjectId('60b8f2223b844518e0e70058'), 'options': ['R$ 670,00.&nbsp;', 'R$ 680,00.&nbsp;', 'R$ 824,00.', 'R$ 980,00.&nbsp;', 'R$ 984,00.'], 'tags': ['Álgebra', 'Álgebra linear'], 'key': 'd_questao_604936', 'name': 'Questão 30 604936', 'testName': 'FATEC 2019/1', 'content': '<p>João, Sílvia e Pedro são funcionários de uma empresa.</p> <p>&nbsp;</p> <p>Considere as matrizes:</p> <p>&nbsp;</p> <p><img src="https://img.estuda.com/temp/formula_f83eb3e4084fd77185e6c17e41e1d92d.png?zdn">&nbsp;em que:</p> <p>&nbsp;</p> <p>• a matriz A representa o valor, em reais, recebido por hora trabalhada de João, Sílvia e Pedro, respectivamente;</p> <p>• a matriz B representa a quantidade de horas trabalhadas por semana dos mesmos funcionários, em cada uma das quatro primeiras semanas no mês de julho de 2018;</p> <p>• na matriz B, as linhas 1 a 3 são para João, Sílvia e Pedro, respectivamente; e as colunas de 1 a 4 são, nessa ordem, para as quatro primeiras semanas do mês de julho, de modo que, por exemplo, o elemento b<sub>13 </sub>é a quantidade de horas que João trabalhou na terceira semana desse mês.</p> <p>&nbsp;</p> <p>O valor pago pela empresa pelas horas trabalhadas por esses três funcionários na segunda semana de julho de 2018 será</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 15, 46, 802000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 15, 46, 802000), '__v': 0}
# {'_id': ObjectId('60b8f22d3b844518e0e70059'), 'options': ['R$ 120,00&nbsp;', 'R$ 140,00&nbsp;', 'R$ 100,00&nbsp;', 'R$ 150,00&nbsp;', 'R$ 160,00'], 'tags': ['Álgebra', 'Álgebra linear'], 'key': 'd_questao_632357', 'name': 'Questão 25 632357', 'testName': 'IFPE Superior 2019', 'content': '<p>&nbsp;&nbsp;&nbsp; Alexsandra foi com sua amiga Carol a uma loja de vestuário em promoção. Estavam à venda todas as blusas por um mesmo valor, assim como qualquer calça custava outro determinado valor. Alexsandra adquiriu duas blusas e uma calça por R$180,00. Já Carol comprou três blusas e duas calças e gastou um valor de R$320,00. Determine o preço de uma blusa e uma calça juntas.</p>', 'level': 0, 'rightAnswer': 1, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 15, 57, 124000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 15, 57, 124000), '__v': 0}
# {'_id': ObjectId('60b8f22d3b844518e0e7005b'), 'options': ['9 meses', '10 meses', '11 meses', '12 meses', '13 meses'], 'tags': ['Álgebra', 'Médias'], 'key': 'd_questao_640034', 'name': 'Questão 48 640034', 'testName': 'CESMAC 2° Dia Medicina 2019/1', 'content': '<p>Um pediatra obteve a seguinte tabela contendo informações sobre a idade com que as crianças começaram a andar pela primeira vez:</p> <p>&nbsp;</p> <p><img height="142" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/1_a1dd3b7e470890d302a19e2e417b38f7_1ae04da67a71d43b107b6599bac80f31.png" width="353"></p> <p>&nbsp;</p> <p>De acordo com esses dados, qual a média do número de meses que uma criança precisa para começar a andar? Indique o valor mais próximo do valor obtido.</p>', 'level': 0, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 15, 57, 200000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 15, 57, 200000), '__v': 0}
# {'_id': ObjectId('60b8f2373b844518e0e70064'), 'options': ['23 380,00&nbsp;', '24 000,00&nbsp;', '23 540,00&nbsp;', '23 760,00&nbsp;', '23 120,00'], 'tags': ['Álgebra', 'Médias'], 'key': 'd_questao_1101273', 'name': 'Questão 5 1101273', 'testName': 'FGV-RJ Administração 2019/2', 'content': '<p>Para resolver, utilize a tabela abaixo:</p> <p><img height="41" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_19448efc3b7aa5768180fc371a5c88d3_1101273.jpg.png" width="323"></p> <p>Certo departamento de uma empresa possui 50 funcionários, cujos salários mensais em reais são dados pela tabela abaixo:</p> <p><img height="121" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_bd0c46edb5fc61632103a8490746b8ab_1101273.jpg.png" width="178"></p> <p>Sejam <em>A</em>, <em>B</em> e <em>C</em> a média, a mediana e a moda dos salários mensais respectivamente. Então <em>A </em>+ <em>B</em> + <em>C</em> é igual a:</p>', 'level': 0, 'rightAnswer': 4, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 16, 7, 906000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 16, 7, 906000), '__v': 0}
# {'_id': ObjectId('60b8f2423b844518e0e70066'), 'options': ['- 20&nbsp;', '-10&nbsp;', '0&nbsp;', '- 5', '-15'], 'tags': ['Álgebra', 'Equações Equações polinomiais Polinomial'], 'key': 'd_questao_1109599', 'name': 'Questão 11 1109599', 'testName': 'FGV-RJ Administração 2019/2', 'content': '<p>A equação polinomial <em>x</em><sup>3</sup> + <em>x</em><sup>2</sup> + <em>px </em>+ <em>q </em>= 0&nbsp;tem a raiz – 2 com multiplicidade 2. Pode-se afirmar que a soma <em>p</em> +<em> q </em>vale:</p>', 'level': 0, 'rightAnswer': 0, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 16, 18, 362000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 16, 18, 362000), '__v': 0}
# {'_id': ObjectId('60b8f24d3b844518e0e7006c'), 'options': ['R$33 000,00&nbsp;', 'R$34 000,00', 'R$32 500,00&nbsp;', 'R$33 500,00&nbsp;', 'R$32 000,00'], 'tags': ['Álgebra', 'Função Função Afim'], 'key': 'd_questao_1122682', 'name': 'Questão 1 1122682', 'testName': 'FGV-SP Administração 2019/2', 'content': '<p>No final do ano 2012, José Carlos comprou um carro 0km. Devido à depreciação, dois anos depois da compra, o valor do carro era R$46 000,00 e, cinco anos após a compra, ele valia R$40 000,00.</p> <p>&nbsp;</p> <p>Admitindo que o valor do carro decresça linearmente com o tempo, pode-se afirmar que 8 anos e 3 meses após a compra o seu valor será:</p>', 'level': 0, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 16, 29, 877000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 16, 29, 877000), '__v': 0}
# {'_id': ObjectId('60b8f24d3b844518e0e7006d'), 'options': ['- 20&nbsp;', '-10&nbsp;', '0', '- 5', '-15'], 'tags': ['Álgebra', 'Equações Equações polinomiais Polinomial'], 'key': 'd_questao_1122771', 'name': 'Questão 11 1122771', 'testName': 'FGV-SP Administração 2019/2', 'content': '<p>A equação polinomial <em>x</em><sup>3</sup><em><sup> </sup>+ x</em><sup>2</sup><em> + px + q</em> = 0&nbsp;tem a raiz – 2 com multiplicidade 2.</p> <p>&nbsp;</p> <p>Pode-se afirmar que a soma <em>p + q </em>vale:</p>', 'level': 0, 'rightAnswer': 0, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 16, 29, 921000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 16, 29, 921000), '__v': 0}
# {'_id': ObjectId('60b8f2583b844518e0e70072'), 'options': ['segunda-feira.', 'terça-feira.', 'quarta-feira.', 'quinta-feira.', 'sexta-feira.'], 'tags': ['Álgebra', 'Álgebra linear'], 'key': 'd_questao_1276998', 'name': 'Questão 140 1276998', 'testName': 'ENEM 2° Dia 2019', 'content': '<p>&nbsp; &nbsp; Um professor aplica, durante os cinco dias úteis de uma semana, testes com quatro questões de múltipla escolha a cinco alunos. Os resultados foram representados na matriz.</p> <p style="text-align: center;"><img height="85" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_177db0a0565acee27c6bd1d502ba3af4_1276998.jpg.png" width="176"></p> <p>&nbsp; &nbsp; Nessa matriz os elementos das linhas de 1&nbsp;a 5 representam as quantidades de questões acertadas pelos alunos Ana, Bruno, Carlos, Denis e Érica, respectivamente, enquanto que as colunas de 1 a 5 indicam os dias da semana, de segunda-feira a sexta-feira, respectivamente, em que os testes foram aplicados.</p> <p>&nbsp;</p> <p>O teste que apresentou maior quantidade de acertos foi o aplicado na</p>', 'level': 0, 'rightAnswer': 0, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 16, 40, 498000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 16, 40, 498000), '__v': 0}
# {'_id': ObjectId('60b8f2633b844518e0e70078'), 'options': ['Pequeno.', 'Ligeiro.', 'Moderado.', 'Grande.', 'Extremo.'], 'tags': ['Álgebra', 'Função Função Logarítmica'], 'key': 'd_questao_1277742', 'name': 'Questão 150 1277742', 'testName': 'ENEM 2° Dia 2019', 'content': '<p style="text-align: left;">&nbsp; &nbsp; Charles Richter e Beno Gutenberg desenvolveram a escala Richter, que mede a magnitude de um terremoto. Essa escala pode variar de 0 a 10, com possibilidades de valores maiores. O quadro mostra a escala de magnitude local (M<sub>s</sub>) de um terremoto que é utilizada para descrevê-lo.</p> <p style="text-align: center;"><img height="176" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_dde7a4b4c9d5efb145007fda5cc101cf_1277742.jpg.png" width="332"></p> <p style="text-align: left;">&nbsp; &nbsp; Para se calcular a magnitude local, usa-se a fórmula M<sub>s</sub> = 3,30 + log(<em>A·f</em>), em que <em>A</em> representa a amplitude máxima da onda registrada por um sismógrafo em micrômetro (µm) e <em>f </em>representa a frequência da onda, em hertz (Hz). Ocorreu um terremoto com amplitude máxima de 2 000 µm e frequência de 0,2 Hz.</p> <p style="text-align: right;"><small>Disponivel em: http://ce jarj cecier) edu.br. Acesso em: 1 fev. 2015(adaptado).</small></p> <p style="text-align: left;">&nbsp;</p> <p style="text-align: left;">&nbsp; &nbsp; Utilize 0,3 como aproximação para log 2.</p> <p style="text-align: left;">&nbsp;</p> <p style="text-align: left;">De acordo com os dados fornecidos, o terremoto ocorrido pode ser descrito como</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 16, 51, 198000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 16, 51, 198000), '__v': 0}
# {'_id': ObjectId('60b8f2633b844518e0e7007b'), 'options': ['1,60', '1,78', '1,79', '1,81', '1,82'], 'tags': ['Álgebra', 'Médias'], 'key': 'd_questao_1277905', 'name': 'Questão 155 1277905', 'testName': 'ENEM 2° Dia 2019', 'content': '<p>&nbsp; &nbsp; O preparador físico de um time de basquete dispõe de um plantel de 20 jogadores, com média de altura igual a 1,80 m. No último treino antes da estreia em um campeonato, um dos jogadores desfalcou o time em razão de uma séria contusão, forçando o técnico a contratar outro jogador para recompor o grupo.</p> <p>&nbsp;</p> <p>Se o novo jogador é 0,20 m mais baixo que o anterior, qual é a média de altura, em metro, do novo grupo?</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 16, 51, 427000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 16, 51, 427000), '__v': 0}
# {'_id': ObjectId('60b8f2783b844518e0e70087'), 'options': ['<img height="150" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_dde9e20c5aa45d206951bc165b1be878_1278767.jpg.png" width="125">', '<img height="151" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_3755578d1d55a60871394f2c890d19e6_1278767.jpg.png" width="127">', '<img height="148" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_03e6b96ffcac6bbf222205be773a158f_1278767.jpg.png" width="124">', '<img height="149" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_ade87b2b6190e1ba769236266e06d0f2_1278767.jpg.png" width="134">', '<img height="153" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_eaa58ef211a078d6dcfcec55d40797ff_1278767.jpg.png" width="128">'], 'tags': ['Álgebra', 'Função'], 'key': 'd_questao_1278767', 'name': 'Questão 177 1278767', 'testName': 'ENEM 2° Dia 2019', 'content': '<p>&nbsp; &nbsp; Uma empresa presta serviço de abastecimento de água em uma cidade. O valor mensal a pagar por esse serviço é determinado pela aplicação de tarifas, por faixas de consumo de água, sendo obtido pela adição dos valores correspondentes a cada faixa.</p> <p>&nbsp;</p> <p>&nbsp; &nbsp; • Faixa 1: para consumo de até 6 m<sup>3</sup>, valor fixo de R$ 12,00;</p> <p>&nbsp; &nbsp; • Faixa 2: para consumo superior a 6 m<sup>3</sup> e até 10 m<sup>3</sup>, tarifa de R$ 3,00 por metro cúbico ao que exceder a 6 m;</p> <p>&nbsp; &nbsp; • Faixa 3: para consumo superior a 10 m<sup>3</sup>, tarifa de R$ 6,00 por metro cúbico ao que exceder a 10 m<sup>3</sup>.</p> <p>&nbsp;</p> <p>&nbsp; &nbsp; Sabe-se que nessa cidade o consumo máximo de água por residência é de 15 m<sup>3</sup> por mês.</p> <p>&nbsp;</p> <p>O gráfico que melhor descreve o valor <em>P</em>, em real, a ser pago por mês, em função do volume <em>V</em> de água consumido, em metro cúbico, é</p>', 'level': 0, 'rightAnswer': 0, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 17, 12, 840000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 17, 12, 840000), '__v': 0}
# {'_id': ObjectId('60b8f2833b844518e0e7008a'), 'options': ['5,0 e 5,5.', '4,0 e 4,5.', '4,5 e 5,0.', '5,5 e 6,0.'], 'tags': ['Álgebra', 'Equações Equações polinomiais Polinomial'], 'key': 'd_questao_1283577', 'name': 'Questão 14 1283577', 'testName': 'UECE 1° fase 2019', 'content': '<p>Considerando o polinômio <img src="https://img.estuda.com/temp/formula_1b82930a0c87f147ed4e15f523a4474d.png?zdn">&nbsp;é correto afirmar que o valor da soma <img src="https://img.estuda.com/temp/formula_d8b0503ce39a90e72a6eaf477cf9dd99.png?zdn"> é um número localizado entre</p>', 'level': 0, 'rightAnswer': 0, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 17, 23, 332000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 17, 23, 332000), '__v': 0}
# {'_id': ObjectId('60b8f2833b844518e0e7008d'), 'options': ['10.&nbsp;', '9.&nbsp;', '8.', '7.&nbsp;', '6.'], 'tags': ['Álgebra', 'Equações Equações polinomiais Polinomial'], 'key': 'd_questao_1302461', 'name': 'Questão 2 1302461', 'testName': 'EsPCEx 2° Dia 2019', 'content': '<p>Dividindo-se o polinômio P(x)= <em>2 x<sup>4</sup> - 5 x<sup>3</sup> + k x - 1 </em>por (<em>x - 3</em>) e (<em>x + 2</em>), os restos são iguais.</p> <p>&nbsp;</p> <p>Neste caso, o valor de <em>k</em> é igual a</p>', 'level': 0, 'rightAnswer': 1, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 17, 23, 443000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 17, 23, 443000), '__v': 0}
# {'_id': ObjectId('60b8f28d3b844518e0e70091'), 'options': ['2', '3', '4', '5', '6'], 'tags': ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais'], 'key': 'd_questao_1314062', 'name': 'Questão 22 1314062', 'testName': 'IFAL 2019/1', 'content': '<p>Sendo <strong>x</strong><sub><strong>1</strong> </sub>e<strong> x<sub>2</sub></strong> as raízes da equação <strong>x<sup>2 </sup>– 5x + 6 = 0</strong>, o resultado do produto <strong>x<sub>1</sub> x<sub>2</sub></strong> é:</p>', 'level': 0, 'rightAnswer': 4, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 17, 33, 814000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 17, 33, 814000), '__v': 0}
# {'_id': ObjectId('60b8f28d3b844518e0e70092'), 'options': ['-2&nbsp;', '-1&nbsp;', '0', '1', '2'], 'tags': ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais'], 'key': 'd_questao_1314065', 'name': 'Questão 23 1314065', 'testName': 'IFAL 2019/1', 'content': '<p>Determine o valor de <strong>k</strong> na equação <strong>x<sup>2</sup> + k x - 2018 = 0</strong>, de modo que suas raízes sejam iguais em módulo, porém com sinais opostos.</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 17, 33, 850000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 17, 33, 850000), '__v': 0}
# {'_id': ObjectId('60b8f2983b844518e0e70096'), 'options': ['1/2&nbsp;', '1', '5/3&nbsp;', '2&nbsp;', '7/3'], 'tags': ['Álgebra', 'Função Função Logarítmica'], 'key': 'd_questao_1314083', 'name': 'Questão 28 1314083', 'testName': 'IFAL 2019/1', 'content': '<p>Determine o valor do <em><strong>log <sub>8</sub> (128)</strong></em>.</p>', 'level': 0, 'rightAnswer': 4, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 17, 44, 634000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 17, 44, 634000), '__v': 0}
# {'_id': ObjectId('60b8f2983b844518e0e70098'), 'options': ['4.', '1.', '2.', '0.', '3.'], 'tags': ['Álgebra', 'Equações Equações polinomiais Polinomial'], 'key': 'd_questao_1328801', 'name': 'Questão 13 1328801', 'testName': 'FAMEMA 2019', 'content': '<p>Na equação polinomial x<sup>3</sup> – 2x<sup>2</sup> – x + 2 = 0, uma das raízes é –1.</p> <p>&nbsp;</p> <p>O módulo da diferença entre a menor e a maior das raízes é</p>', 'level': 0, 'rightAnswer': 4, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 17, 44, 703000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 17, 44, 703000), '__v': 0}
# {'_id': ObjectId('60b8f2983b844518e0e70099'), 'options': ['6,25%', '31,25%', '3,125%', '32%', '2,5%'], 'tags': ['Álgebra', 'Sequências'], 'key': 'd_questao_1349930', 'name': 'Questão 22 1349930', 'testName': 'FMP 2019', 'content': '<p>Uma progressão geométrica tem o seu primeiro termo e sua razão iguais a 1/2.</p> <p>&nbsp;</p> <p>O quinto termo dessa progressão é uma fração que, se escrita em forma percentual, é dada por</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 17, 44, 747000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 17, 44, 747000), '__v': 0}
# {'_id': ObjectId('60b8f2b93b844518e0e700a9'), 'options': ['Certo', 'Errado'], 'tags': ['Álgebra', 'Função Função Quadrática'], 'key': 'd_questao_1366787', 'name': 'Questão 48 1366787', 'testName': 'UnB 2° Dia 2019', 'content': '<p>&nbsp; &nbsp; As quantidades dos <em>video games </em>das marcas Crya e XGame vendidas anualmente, em milhares de unidades, são expressas, respectivamente, pelas funções <em>C</em>(<em>x</em>) = -<em>x</em><sup>2</sup> + 60<em>x</em> + 325 e <em>G</em>(<em>x</em>) = -2<em>x</em><sup>2</sup> + 112<em>x</em> + 114, para <em>x</em> = 0, 1, ..., 57, em que <em>x</em> = 0 corresponde ao ano de 1970, <em>x</em> = 1, ao ano de 1971 e assim sucessivamente.</p> <p>&nbsp;</p> <p>Tendo como referência essas informações, julgue o item e assinale a opção correta.</p>', 'level': 0, 'rightAnswer': 0, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 18, 17, 546000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 18, 17, 546000), '__v': 0}
# {'_id': ObjectId('60b8f2c43b844518e0e700b0'), 'options': ['35&nbsp;', '45', '55&nbsp;', '65'], 'tags': ['Álgebra', 'Função Função Afim Gráficos'], 'key': 'd_questao_1374585', 'name': 'Questão 24 1374585', 'testName': 'USS 2019/1', 'content': '<p>Uma caixa d’água que está inicialmente vazia tem a capacidade de 1000 L. Essa caixa é abastecida durante 3,5 h até ficar completamente cheia. O gráfico a seguir, formado por dois segmentos de retas, representa o volume de água na caixa em função do tempo.</p> <p style="text-align: center;"><img height="153" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_72abe8e84c5db38aefbc664a72b29670_1374585.jpg.png" width="265"></p> <p style="text-align: left;">Após a redução do fluxo de água, o tempo necessário, em minutos, para que o volume de água atinja exatamente 900 L é igual a</p>', 'level': 0, 'rightAnswer': 1, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 18, 28, 100000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 18, 28, 100000), '__v': 0}
# {'_id': ObjectId('60b8f2c43b844518e0e700b1'), 'options': ['44', '40', '36', '32'], 'tags': ['Álgebra', 'Sequências'], 'key': 'd_questao_1374626', 'name': 'Questão 26 1374626', 'testName': 'USS 2019/1', 'content': '<p>As idades de um jovem, de sua mãe e de sua avó estão, nessa ordem, em progressão geométrica de razão 9/4. Sabe-se que a avó possui 65 anos a mais que o neto.</p> <p>&nbsp;</p> <p>A idade, em anos, da mãe desse jovem é igual a</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 18, 28, 140000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 18, 28, 140000), '__v': 0}
# {'_id': ObjectId('60b8f2da3b844518e0e700be'), 'options': ['S = -5t', 'S = -4t', 'S = 4t', 'S = 3t', 'S = 5t'], 'tags': ['Álgebra', 'Função Função Afim'], 'key': 'd_questao_1415079', 'name': 'Questão 45 1415079', 'testName': 'UEMA 2019', 'content': '<p><strong>Texto para responder à questão.</strong></p> <p>&nbsp;</p> <p>&nbsp; &nbsp; Na sociedade contemporânea, as representações visuais como os gráficos, as tabelas, os diagramas e as outras formas de inscrições são consideradas ferramentas comuns para aplicações que apresentam informações quantitativas.</p> <p>&nbsp; &nbsp; Destaca-se a utilização dos gráficos para descrever o comportamento de grandezas que são tratadas no ensino de Física. Essa disciplina faz uso de gráficos na totalidade dos assuntos por ela abordada, principalmente, no estudo do movimento - a Cinemática. Desta forma, a aprendizagem do uso da linguagem gráfica torna-se fundamental para a compreensão de fenômenos tratados pela Física e por outras Ciências.</p> <p style="text-align: right;"><small>Fonte: http://www.bibliotecadigital.ufmg.br</small></p> <p style="text-align: right;">&nbsp;</p> <p style="text-align: left;">Analise a seguinte situação:</p> <p style="text-align: left;">&nbsp;</p> <p style="text-align: left;">Corridas de 50 metros, geralmente, são para provas de aptidão física (concursos da polícia, guarda civil, etc.), na qual o candidato deverá correr 50 m em um tempo mínimo. Quanto menor o tempo, melhor será a sua classificação. Num Concurso Público para Guarda Municipal, um determinado candidato realizou o Teste de Aptidão Fisica, percorrendo o espaço e o tempo, de acordo com o gráfico representado a seguir.</p> <p style="text-align: left;">&nbsp;</p> <p style="text-align: left;">Analise o gráfico que mostra o desempenho do candidato. Para tanto, considere <strong>S</strong>, em metros, e <strong>t</strong>, em segundos.</p> <p style="text-align: center;"><img height="206" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_1c0a26cbf56f90c7e4a546126ca5f89c_1415079.jpg.png" width="272"></p> <p style="text-align: left;">De acordo com o gráfico de desempenho do candidato, a função horária correspondente é igual</p>', 'level': 0, 'rightAnswer': 4, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 18, 50, 639000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 18, 50, 639000), '__v': 0}
# {'_id': ObjectId('60b8f2e53b844518e0e700c4'), 'options': ['30.', '35.', '40.', '45.', '50.'], 'tags': ['Álgebra', 'Função Função Quadrática'], 'key': 'd_questao_1421773', 'name': 'Questão 6 1421773', 'testName': 'UNIFOR 2019.2', 'content': '<p>A quantidade de alunos da disciplina de Cálculo I que estão presentes no dia x do mês de abril é igual ao valor da função f (x) = - x<sup>2</sup> + 14x - 24. Os dias x em que as frequências dos alunos foram anotadas são aquelas em que f (x) ≥ 0.</p> <p>&nbsp;</p> <p>Se a quantidade de alunos que compareceu no dia de maior frequência corresponde a 50% do total de alunos da disciplina, então o número de alunos que a disciplina possui é</p>', 'level': 0, 'rightAnswer': 4, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 19, 1, 424000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 19, 1, 424000), '__v': 0}
# {'_id': ObjectId('60b8f2ef3b844518e0e700c7'), 'options': ['108.', '118.', '120.', '122.', '128.'], 'tags': ['Álgebra', 'Função'], 'key': 'd_questao_1421838', 'name': 'Questão 15 1421838', 'testName': 'UNIFOR 2019.2', 'content': '<p>Uma cultura de bactérias cuja família inicial era de 300 elementos foi testada num laboratório sob a ação de uma certa droga. Verificou-se que a lei de sobrevivência desta família obedecia à relação f(t) = at<sup>2</sup> + b, onde f(t) é igual ao número de elementos vivos no tempo t (dados em dias) e <u>a</u> e <u>b</u> são constantes que dependem da droga aplicada. Verificou-se também que a família morreu quando t = 10 dias, isto após o inicio da experiência.</p> <p>&nbsp;</p> <p>Portanto, no oitavo dia do inicio da experiência, o número de elementos dessa família era</p>', 'level': 0, 'rightAnswer': 0, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 19, 11, 892000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 19, 11, 892000), '__v': 0}
# {'_id': ObjectId('60b8f3053b844518e0e700d2'), 'options': ['387', '424', '437', '574', '711'], 'tags': ['Álgebra', 'Sequências'], 'key': 'd_questao_1440435', 'name': 'Questão 176 1440435', 'testName': 'ENEM PPL 2° dia 2019', 'content': '<p>&nbsp; &nbsp; Em um município foi realizado um levantamento relativo ao número de médicos, obtendo-se os dados:</p> <p style="text-align: center;"><img height="102" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_36dc27b6964be0402276c80702155fc3_1440435.jpg.png" width="309"></p> <p style="text-align: left;">&nbsp; &nbsp; Tendo em vista a crescente demanda por atendimento médico na rede de saúde pública, pretende-se promover a expansão, a longo prazo, do número de médicos desse município, seguindo o comportamento de crescimento linear no período observado no quadro.</p> <p style="text-align: left;">&nbsp;</p> <p style="text-align: left;">Qual a previsão do número de médicos nesse município para o ano 2040?</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 19, 33, 321000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 19, 33, 321000), '__v': 0}
# {'_id': ObjectId('60b8f3053b844518e0e700d4'), 'options': ['domingo.', 'segunda-feira.', 'terça-feira.', 'quarta-feira.', 'sábado.'], 'tags': ['Álgebra', 'Aritmética Médias'], 'key': 'd_questao_1440500', 'name': 'Questão 179 1440500', 'testName': 'ENEM PPL 2° dia 2019', 'content': '<p>&nbsp; &nbsp; O quadro apresenta a quantidade de um tipo de pão vendido em uma semana em uma padaria.</p> <p style="text-align: center;"><img height="172" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_d2ee6e4929bda4c4c973c2e649cca7ea_1440500.jpg.png" width="335"></p> <p>&nbsp; &nbsp; O dono da padaria decidiu que, na semana seguinte, a produção diária desse tipo de pão seria igual ao número de pães vendidos no dia da semana em que tal quantidade foi a mais próxima da média das quantidades vendidas na semana.</p> <p>&nbsp;</p> <p>O dia da semana utilizado como referência para a quantidade de pães a serem produzidos diariamente foi</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 19, 33, 394000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 19, 33, 394000), '__v': 0}
# {'_id': ObjectId('60b8f3053b844518e0e700d5'), 'options': ['Decrescente.', 'Inconstante.', 'Crescente.&nbsp;', 'Alternada.&nbsp;', 'Constante.'], 'tags': ['Álgebra', 'Função'], 'key': 'd_questao_1446142', 'name': 'Questão 1 1446142', 'testName': 'ESA 2019', 'content': '<p>Se, para quaisquer valores&nbsp;X<sub>1</sub> e X<sub>2</sub> de um conjunto S (contido no domínio D), com X<sub>1&nbsp;</sub>&lt; X<sub>2</sub>, temos f(X<sub>1</sub>) &lt; f(X<sub>2</sub>), então podemos afirmar que a função f é:</p>', 'level': 0, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 19, 33, 506000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 19, 33, 506000), '__v': 0}
# {'_id': ObjectId('60b8f3103b844518e0e700d7'), 'options': ['10.', '-10.', '-2.&nbsp;', '2.', '7.'], 'tags': ['Álgebra', 'Equação do Terceiro Grau Equações Equações polinomiais'], 'key': 'd_questao_1446161', 'name': 'Questão 6 1446161', 'testName': 'ESA 2019', 'content': '<p>Identifique a alternativa que apresenta o produto das raízes da equação 5.x<sup>3 </sup>- 4x<sup>2</sup> + 7x – 10 = 0.</p>', 'level': 0, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 19, 44, 112000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 19, 44, 112000), '__v': 0}
# {'_id': ObjectId('60b8f3103b844518e0e700da'), 'options': ['<img class="formula" src="https://img.estuda.com/temp/formula_c925e14a041d3fd608a89377d4b23b2d.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_e8d7bc1a67db44e249ed90a160afd0b5.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_5f90abc4a0c57e6e8e8c51c6d75e3a48.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_59e6ed269715680d8e7a3d3fe05b94d5.png?zdn">'], 'tags': ['Álgebra', 'Sequências'], 'key': 'd_questao_1446604', 'name': 'Questão 67 1446604', 'testName': 'UNICAMP 2019', 'content': '<p>A figura a seguir exibe um pentágono em que quatro lados consecutivos têm comprimentos <em>a, b, c</em> e <em>d</em>.</p> <p>&nbsp;</p> <p>Se a sequência (<em>a, b, c, d</em>) é uma progressão geométrica de razão <img src="https://img.estuda.com/temp/formula_1c1200f6d92cb675944eb522a688595e.png?zdn"> então tan <em>θ</em> é igual a</p> <p style="text-align: center;"><img height="116" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_399b22e15af05e8940ac8a9f3ef78c22_1446604.jpg.png" width="172"></p>', 'level': 0, 'rightAnswer': 0, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 19, 44, 225000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 19, 44, 225000), '__v': 0}
# {'_id': ObjectId('60b8f3103b844518e0e700db'), 'options': ['<img class="formula" src="https://img.estuda.com/temp/formula_4b6c6e6106b8933b98cdbbb388209294.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_3e35563210f995ee79a073fa882e1fd6.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_a85803f14639bef7f4539bad631d088c.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_ecb555b7c7fa7a949794449bbd3357f7.png?zdn">'], 'tags': ['Álgebra', 'Álgebra linear'], 'key': 'd_questao_1446614', 'name': 'Questão 68 1446614', 'testName': 'UNICAMP 2019', 'content': '<p>Sabendo que <em>a</em> e <em>b</em> são números reais, considere a matriz quadrada de ordem&nbsp;<img src="https://img.estuda.com/temp/formula_24cccdfe8b9dddaed87bb893d7abcfc2.png?zdn"></p> <p>&nbsp;</p> <p style="text-align: left;"><img src="https://img.estuda.com/temp/formula_27f2e012d206e32326a472626b2ce1af.png?zdn"></p> <p style="text-align: left;">&nbsp;</p> <p>Se a soma dos elementos em cada linha da matriz <em>A</em> tem sempre o mesmo valor, então o determinante de <em>A</em> é igual a</p>', 'level': 0, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 19, 44, 261000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 19, 44, 261000), '__v': 0}
# {'_id': ObjectId('60b8f31a3b844518e0e700dd'), 'options': ['R$ 5.800,00.&nbsp;', 'R$ 5.520,00.&nbsp;', 'R$ 5.500,00.', 'R$ 6.300,00.', 'R$ 6.560,00.'], 'tags': ['Álgebra', 'Equações Equações polinomiais'], 'key': 'd_questao_1465840', 'name': 'Questão 50 1465840', 'testName': 'UEA 2019', 'content': '<p>Gustavo tem duas contas correntes bancárias, A e B. Fazendo cálculos, ele constatou que se depositar R$ 1.260,00 na conta B, esta passará a ter um saldo correspondente ao dobro do saldo da conta A. Entretanto, se depositar R$ 1.260,00 na conta A, ambas ficarão com saldos iguais.</p> <p>&nbsp;</p> <p>Originalmente, as duas contas têm, juntas, um total de</p>', 'level': 0, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 15, 19, 54, 671000), 'updatedAt': datetime.datetime(2021, 6, 3, 15, 19, 54, 671000), '__v': 0}
# ...
# {'_id': ObjectId('60b9353e4f3fba4d48ce50a8'), 'options': ['{2}', '{3}', '{2,3}', '[2,3]', '[0,3]'], 'tags': ['Álgebra', 'Equações Equações polinomiais Modular'], 'key': 'd_questao_1416243', 'name': 'Questão 28 1416243', 'testName': 'URCA 1° Dia 2019/1', 'content': '<p>O conjunto solução da equação |x - 2| + |x - 3| = 1 é</p>', 'level': 1, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 2, 6, 425000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 2, 6, 425000), '__v': 0}
# {'_id': ObjectId('60b9353e4f3fba4d48ce50a9'), 'options': ['<img class="formula" src="https://img.estuda.com/temp/formula_1679091c5a880faf6fb5e6087eb1b2dc.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_8f14e45fceea167a5a36dedd4bea2543.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_c9f0f895fb98ab9159f51fd0297e236d.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_e4da3b7fbbce2345d7772b0674a318d5.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_d3d9446802a44259755d38e6d163e820.png?zdn">'], 'tags': ['Álgebra', 'Função Função Exponencial'], 'key': 'd_questao_1416257', 'name': 'Questão 30 1416257', 'testName': 'URCA 1° Dia 2019/1', 'content': '<p>Sabendo que a soma dos coeficientes no desenvolvimento de&nbsp;<img src="https://img.estuda.com/temp/formula_197514edcecb5185473515b1d2f9e525.png?zdn">&nbsp;é igual a p, determine&nbsp;<img src="https://img.estuda.com/temp/formula_496b58af9ce1687e2d82f939f26e45c0.png?zdn"></p>', 'level': 1, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 2, 6, 520000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 2, 6, 520000), '__v': 0}
# {'_id': ObjectId('60b935484f3fba4d48ce50ab'), 'options': ['3/7.', '17/10.', '5/3.', '9/5.', '2.'], 'tags': ['Álgebra', 'Função'], 'key': 'd_questao_1421760', 'name': 'Questão 4 1421760', 'testName': 'UNIFOR 2019.2', 'content': '<p>A figura abaixo representa o gráfico de uma função ƒ cujo domínio é o intervalo fechado -1&nbsp; ≤ x&nbsp; ≤ 7.&nbsp;Sabe-se que o segmento <span style="text-decoration:overline;">AB </span>é paralelo ao segmento <span style="text-decoration:overline;">CD</span> e que o segmento <span style="text-decoration:overline;">BC</span> é paralelo ao eixo dos x.</p> <p>&nbsp;</p> <p>Nessas condições, podemos afirmar que o valor&nbsp;de&nbsp;f(7) – f(4,5)&nbsp;é igual a</p> <p style="text-align: center;"><img height="132" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_1bf53d34c902760a557105b662d87a0d_1421760.jpg.png" width="218"></p>', 'level': 1, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 2, 16, 356000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 2, 16, 356000), '__v': 0}
# {'_id': ObjectId('60b935484f3fba4d48ce50ac'), 'options': ['x = 4,8 + 0,95n', 'x = 4,8 + 1,05n', 'x = 4,8(0,95)<sup>n</sup>', 'x = 4,8(1,05)<sup>n</sup>', 'x = 4,8(0,05)<sup>n</sup>'], 'tags': ['Álgebra', 'Função Função Exponencial'], 'key': 'd_questao_1421778', 'name': 'Questão 7 1421778', 'testName': 'UNIFOR 2019.2', 'content': '<p>João tem observado uma queda de 5% no preço do quilo do feijão de corda, com relação ao mês anterior, nos últimos 5 meses, consecutivamente.</p> <p>&nbsp;</p> <p>Se <em>n</em> é o número de meses desde que o preço começou a baixar e <em>x</em> é o preço do quilo de feijão, qual das seguintes expressões modela o&nbsp;preço do quilo de feijão neste período de tempo?</p>', 'level': 1, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 2, 16, 465000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 2, 16, 465000), '__v': 0}
# {'_id': ObjectId('60b935524f3fba4d48ce50b0'), 'options': ['<img class="formula" src="https://img.estuda.com/temp/formula_eccbc87e4b5ce2fe28308fd9f2a7baf3.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_c9f0f895fb98ab9159f51fd0297e236d.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_45c48cce2e2d7fbdea1afc51c7c6ad26.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_d3d9446802a44259755d38e6d163e820.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_1679091c5a880faf6fb5e6087eb1b2dc.png?zdn">'], 'tags': ['Álgebra', 'Função Função Inversa'], 'key': 'd_questao_1421928', 'name': 'Questão 18 1421928', 'testName': 'URCA 1° Dia 2019/2', 'content': '<p>Seja&nbsp;<img src="https://img.estuda.com/temp/formula_ea65afdbf79527332c9841571aadf852.png?zdn">&nbsp;dada por&nbsp;<img src="https://img.estuda.com/temp/formula_b79df3f61daed41e2f3a2477dd7f8484.png?zdn">&nbsp;</p> <p>&nbsp;</p> <p>Se&nbsp;<img src="https://img.estuda.com/temp/formula_e55e328349414752113c4878dc62303f.png?zdn">&nbsp;denota a função inversa de <em>f</em>, encontre&nbsp;<img src="https://img.estuda.com/temp/formula_70f481559869928958a7e6450528a718.png?zdn"></p>', 'level': 1, 'rightAnswer': 1, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 2, 26, 456000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 2, 26, 456000), '__v': 0}
# {'_id': ObjectId('60b935524f3fba4d48ce50b1'), 'options': ['9', '27&nbsp;', '81&nbsp;', '18&nbsp;', '3'], 'tags': ['Álgebra', 'Equações Equações polinomiais Logarítmica'], 'key': 'd_questao_1421945', 'name': 'Questão 19 1421945', 'testName': 'URCA 1° Dia 2019/2', 'content': '<p>Se <em>x</em> = log<sub>3</sub> 7. log<sub>7</sub> 6. log<sub>6</sub> 2&nbsp;Então 3<sup>x+2</sup> vale:</p>', 'level': 1, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 2, 26, 636000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 2, 26, 636000), '__v': 0}
# {'_id': ObjectId('60b935534f3fba4d48ce50b4'), 'options': ['<img class="formula" src="https://img.estuda.com/temp/formula_9e307435e15ae0a1738dd9e0f4ba8f23.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_b71228770793627de1ca3b3e48448a4c.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_f0ff4b537d3fd6140efb1531e4b59395.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_92455ff3a4c563eb1cc98badd30ab8c6.png?zdn">', '<img class="formula" src="https://img.estuda.com/temp/formula_f43a748dce2949beaaed2a47b493afbd.png?zdn">'], 'tags': ['Álgebra', 'Álgebra linear'], 'key': 'd_questao_1421971', 'name': 'Questão 22 1421971', 'testName': 'URCA 1° Dia 2019/2', 'content': '<p>Determine o conjunto solução do sistema&nbsp;</p> <p><img src="https://img.estuda.com/temp/formula_59e201bdea95dab9e6ab76795237130d.png?zdn"></p>', 'level': 1, 'rightAnswer': 0, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 2, 27, 77000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 2, 27, 77000), '__v': 0}
# {'_id': ObjectId('60b935534f3fba4d48ce50b5'), 'options': ['6', '5', '4', '7', '8'], 'tags': ['Álgebra', 'Equações Equações polinomiais Polinomial'], 'key': 'd_questao_1421999', 'name': 'Questão 24 1421999', 'testName': 'URCA 1° Dia 2019/2', 'content': '<p>Determine o módulo da diferença entre as raízes reais da equação (x - 4)<sup>4</sup> + (x - 2)<sup>4</sup> = 82</p>', 'level': 1, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 2, 27, 217000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 2, 27, 217000), '__v': 0}
# {'_id': ObjectId('60b935684f3fba4d48ce50bc'), 'options': ['4.', '7.', '8.', '9.', '10.'], 'tags': ['Álgebra', 'Função Função Quadrática'], 'key': 'd_questao_1439952', 'name': 'Questão 143 1439952', 'testName': 'ENEM PPL 2° dia 2019', 'content': '<p>&nbsp; &nbsp; No desenvolvimento de um novo remédio, pesquisadores monitoram a quantidade <em>Q</em> de uma substância circulando na corrente sanguínea de um paciente, ao longo do tempo <em>t</em>. Esses pesquisadores controlam o processo, observando que <em>Q</em> é uma função quadrática de <em>t</em>. Os dados coletados nas duas primeiras horas foram:</p> <p style="text-align: center;"><img height="78" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_eeebf9abb983ceca4a9e955fb2cf488a_1439952.jpg.png" width="291"></p> <p>&nbsp; &nbsp; Para decidir se devem interromper o processo, evitando riscos ao paciente, os pesquisadores querem saber, antecipadamente, a quantidade da substância que estará circulando na corrente sanguínea desse paciente após uma hora do último dado coletado.</p> <p>&nbsp;</p> <p>Nas condições expostas, essa quantidade (em miligrama) será igual a</p>', 'level': 1, 'rightAnswer': 1, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 2, 48, 730000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 2, 48, 730000), '__v': 0}
# {'_id': ObjectId('60b935684f3fba4d48ce50bd'), 'options': ['63', '96', '128', '192', '255'], 'tags': ['Álgebra', 'Função Função Logarítmica'], 'key': 'd_questao_1439961', 'name': 'Questão 144 1439961', 'testName': 'ENEM PPL 2° dia 2019', 'content': '<p>&nbsp; &nbsp; Um jardineiro cultiva plantas ornamentais e as coloca à venda quando estas atingem 30 centímetros de altura. Esse jardineiro estudou o crescimento de suas plantas, em função do tempo, e deduziu uma fórmula que calcula a altura em função do tempo, a partir do momento em que a planta brota do solo até o momento em que ela atinge sua altura máxima de 40 centímetros. A fórmula é <em>h</em> = 5·log<sub>2</sub> (<em>t</em> + 1), em que <em>t </em>é o tempo contado em dia e <em>h</em>, a altura da planta em centímetro.</p> <p>&nbsp;</p> <p>A partir do momento em que uma dessas plantas é colocada à venda, em quanto tempo, em dia, ela alcançará sua altura máxima?</p>', 'level': 1, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 2, 48, 832000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 2, 48, 832000), '__v': 0}
# {'_id': ObjectId('60b9358a4f3fba4d48ce50ce'), 'options': ['3<em>N</em><sub>0</sub>', '15<em>N</em><sub>0</sub>', '243<em>N</em><sub>0</sub>', '360<em>N</em><sub>0</sub>', '729<em>N</em><sub>0</sub>'], 'tags': ['Álgebra', 'Função Função Exponencial'], 'key': 'd_questao_1440313', 'name': 'Questão 167 1440313', 'testName': 'ENEM PPL 2° dia 2019', 'content': '<p>&nbsp; &nbsp; Em um laboratório, cientistas observaram o crescimento de uma população de bactérias submetida a uma dieta magra em fósforo, com generosas porções de arsênico. Descobriu-se que o número de bactérias dessa população, após <em>t</em> horas de observação, poderia ser modelado pela função exponencial <em>N</em>(<em>t</em>) = <em>N</em><sub>0</sub>e<em><sup>kt</sup></em>, em que <em>N</em><sub>0</sub> é o número de bactérias no instante do início da observação (<em>t</em> = 0) e representa uma constante real maior que 1, e <em>k</em> é uma constante real positiva.</p> <p>&nbsp;</p> <p>&nbsp; &nbsp; Sabe-se que, após uma hora de observação, o número de bactérias foi triplicado.</p> <p>&nbsp;</p> <p>Cinco horas após o início da observação, o número de bactérias, em relação ao número inicial dessa cultura, foi</p>', 'level': 1, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 3, 22, 955000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 3, 22, 955000), '__v': 0}
# {'_id': ObjectId('60b935a94f3fba4d48ce50dd'), 'options': ['10.', '12.', '14,', '16.'], 'tags': ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais'], 'key': 'd_questao_1446520', 'name': 'Questão 61 1446520', 'testName': 'UNICAMP 2019', 'content': '<p>A representação decimal de certo número inteiro positivo tem dois algarismos.</p> <p>&nbsp;</p> <p>Se o triplo da soma desses algarismos é igual ao próprio número, então o produto dos algarismos é igual a</p>', 'level': 1, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 3, 53, 938000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 3, 53, 938000), '__v': 0}
# {'_id': ObjectId('60b935aa4f3fba4d48ce50df'), 'options': ['<img height="124" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_70c1ad44d8edf57f1904a376a2e2db4b_1446552.jpg.png" width="225">', '<img height="128" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_07baa20c9639ab907c7b682190ef1c98_1446552.jpg.png" width="229">', '<img height="130" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_d483bb4dd4f01a95bda0523beacd3753_1446552.jpg.png" width="225">', '<img height="125" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_imagens/0_b2730decfff3f74f9ad851b385b02f4d_1446552.jpg.png" width="234">'], 'tags': ['Álgebra', 'Função Função Quadrática'], 'key': 'd_questao_1446552', 'name': 'Questão 63 1446552', 'testName': 'UNICAMP 2019', 'content': '<p>Sejam <em>a</em> e <em>b</em> números reais positivos. Considere a função quadrática <em>f</em>(x) = <em>x</em>(<em>ax</em> + <em>b</em>), definida para todo número real <em>x</em>.</p> <p>&nbsp;</p> <p>No plano cartesiano, qual figura corresponde ao gráfico de <em>y</em> = <em>f</em>(<em>x</em>)?</p>', 'level': 1, 'rightAnswer': 1, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 3, 54, 285000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 3, 54, 285000), '__v': 0}
# {'_id': ObjectId('60b935b54f3fba4d48ce50e0'), 'options': ['irracional.', 'racional não inteiro.', 'inteiro positivo.', 'inteiro negativo'], 'tags': ['Álgebra', 'Função Função Quadrática'], 'key': 'd_questao_1446564', 'name': 'Questão 64 1446564', 'testName': 'UNICAMP 2019', 'content': '<p>Sejam <em>k</em> e <em>θ</em> números reais tais que sen&nbsp; <em>θ</em> e cos <em>θ</em> são soluções da equação quadrática 2<em>x</em><sup>2</sup>&nbsp;+ <em>x</em> + <em>k</em> = 0.</p> <p>&nbsp;</p> <p>Então, <em>k</em> é um número</p>', 'level': 1, 'rightAnswer': 1, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 4, 5, 425000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 4, 5, 425000), '__v': 0}
# {'_id': ObjectId('60b935b64f3fba4d48ce50e4'), 'options': ['0.', '1.', '2.', '3.'], 'tags': ['Álgebra', 'Função Polinomial'], 'key': 'd_questao_1446632', 'name': 'Questão 70 1446632', 'testName': 'UNICAMP 2019', 'content': '<p>Sabendo que <em>a</em> e <em>b</em> são números reais, considere o polinômio cúbico <em>p</em>(<em>x</em>) = <em>x</em><sup>3</sup> +<em> ax</em><sup>2</sup> + <em>x</em> + <em>b</em>.</p> <p>&nbsp;</p> <p>Se a soma e o produto de duas de suas raízes são iguais a -1, então <em>p</em>(1) é igual a</p>', 'level': 1, 'rightAnswer': 3, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 4, 6, 34000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 4, 6, 34000), '__v': 0}
# {'_id': ObjectId('60b935c14f3fba4d48ce50e7'), 'options': ['V(3, –2).&nbsp;', 'V(2, –1).&nbsp;', 'V(3, –1).&nbsp;', 'V(4, –1).&nbsp;', 'V(4, –2).'], 'tags': ['Álgebra', 'Função Polinomial'], 'key': 'd_questao_1465903', 'name': 'Questão 53 1465903', 'testName': 'UEA 2019', 'content': '<p>Sabe-se que o produto das raízes da função real f(x) = kx<sup>2 </sup>– 6kx + k + 7, com k ≠ 0, é igual a 8.</p> <p>&nbsp;</p> <p>Nessas condições, as coordenadas do vértice V da parábola definida pela função y = f(x) são</p>', 'level': 1, 'rightAnswer': 2, 'subjectName': 'matematica', 'createdAt': datetime.datetime(2021, 6, 3, 20, 4, 17, 290000), 'updatedAt': datetime.datetime(2021, 6, 3, 20, 4, 17, 290000), '__v': 0}
