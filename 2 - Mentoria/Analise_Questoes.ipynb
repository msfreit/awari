# %%
# pip install pymongo
# pip install pymongo[srv]

from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient("mongodb+srv://revisapp-admin:f645HbS2AcypdWbG@cluster0.hmkez.mongodb.net/revisapp-mat?retryWrites=true&w=majority")
database = client["revisapp"]
collection = database["questions"]

# %%
query = {}

query["subjectName"] = u"matematica"
query["tags"] = u"\u00C1lgebra"

projection = {}

projection["content"] = u"$content"
projection["subjectName"] = u"$subjectName"
projection["tags"] = u"$tags"
projection["_id"] = 0

sort = [ (u"tags", -1) ]

cursor = collection.find(query, projection = projection, sort = sort, limit = 10)
questoes = list(cursor)
questoes
# Out:
# [{'content': '<p><img height="319" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_base/1_ddae2d3a265bac7a7949b4d77d6c0b67_14c50c03801b4ce62ecbcd423d7a6987.png" width="293"></p> <p>&nbsp; &nbsp; &nbsp;</p> <p>&nbsp; &nbsp; O diagrama acima mostra dois conjuntos de ruas de mão única que se cruzam no centro de uma cidade, nos pontos A, B, C e D. Nesse diagrama, as constantes a<sub>1</sub>, a<sub>2</sub>, a<sub>3</sub> e a<sub>4</sub> representam as quantidades de automóveis que entram, por hora, na região do centro pelas quatro ruas indicadas, e b<sub>1</sub>, b<sub>2</sub>, b<sub>3</sub> e b<sub>4</sub>, representam as quantidades de automóveis que saem do centro. As incógnitas x, y, z e w representam quantidades desconhecidas de automóveis que fluem pelos respectivos trechos no centro. Em cada cruzamento, o número de veículos que entra é igual ao número de veículos que sai, ou seja, as seguintes relações são válidas.</p> <p>&nbsp;</p> <p><img height="82" src="https://d23vy2bv3rsfba.cloudfront.net/questoes_base/1_478f2ed44a04666fca1d7740d669ac9f_248423bb2a0f960d1dd71fc69f5d3ab7.png" width="190"></p> <p>&nbsp;</p> <p>Com base nas informações apresentadas, julgue o&nbsp;item.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Sequências']},
#  {'content': '<p>Num certo dia do mês de novembro de 2015, seis barracas da Feirinha de Artesanato da Pajuçara vendiam castanhas de caju em embalagens com pesos variados de acordo com a tabela.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Médias']},
#  {'content': '<p>Determine a solução da inequação&nbsp;<img src="https://img.estuda.com/temp/formula_7135a20f0078c0edbc4aaa1bce721838.png?zdn">&nbsp;dentre as apontadas nas alternativas a seguir.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Inequações Inequações polinomiais']},
#  {'content': '<p>Considere A uma matriz real quadrada de ordem 2, cujo determinante (det) é igual a 5, e A<sup>T</sup> a matriz transposta de A. Sabendo-se que x é um número real, o conjunto solução da inequação det(3<em>A</em>)x<sup>2 </sup>+&nbsp;det(2A·A<sup>T</sup>)x&nbsp;&gt; 0&nbsp;é</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Inequações Inequações polinomiais']},
#  {'content': '<p>Um grupo de estudantes fará uma excursão e alugará ônibus para transportá-lo. A transportadora dispõe de ônibus em dois tamanhos, pequeno e grande. O pequeno tem capacidade para 24 pessoas, ao custo total de R$ 500,00. O grande tem capacidade para 40 pessoas, ao custo total de R$ 800,00. Sabe-se que pelo menos 120 estudantes participarão da excursão e que o grupo não quer gastar mais do que R$ 4.000,00 com o aluguel dos ônibus.</p>\n<p>&nbsp;</p>\n<p>Sendo x o número de ônibus pequenos e y o número de ônibus grandes que serão alugados, o par ordenado (x, y) terá que pertencer, necessariamente, ao conjunto solução do sistema de inequações</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Inequação do Primeiro Grau Inequações Inequações polinomiais']},
#  {'content': '<p>Sobre o sistema&nbsp;<img src="https://img.estuda.com/temp/formula_32297329e2f86f65d7a8a3a09ae61f2e.png?zdn">&nbsp;pode-se afirmar que o valor de&nbsp;</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função Polinomial']},
#  {'content': '<p>Considere os polinômios&nbsp;<img src="https://img.estuda.com/temp/formula_35e3ad8732ec6d347a2f5406b59dfc23.png?zdn"></p> <p>&nbsp;</p> <p>Para que p(x) seja divisível por q(x), é necessário que m seja igual a</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função Polinomial']},
#  {'content': '<p>Este gráfico mostra uma análise da cotação do dólar do dia 23 ao dia 28 de março de 2016.</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra', 'Álgebra linear Função Gráficos']},
#  {'content': '<p>Seja 𝒇: 𝑹 → 𝑹 definida por</p> <p>&nbsp;</p> <p><img src="https://img.estuda.com/temp/formula_d5290902a0bee2c946905047ff650668.png?zdn">,&nbsp;o valor de&nbsp;<img src="https://img.estuda.com/temp/formula_84329aabc41498a963c845c5fd261b09.png?zdn"> é:</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Função Funções Definidas por Várias Sentenças']},
#  {'content': '<p>Três pessoas, X, Y e Z tinham a mesma quantia em reais. X, de início, gastou 99 reais. Y deu uma parte de sua quantia para Z, e o dobro dessa parte, para X. Com essas novas quantias em reais, as três pessoas saíram para as compras e X gastou o quadrado da diferença entre 4 reais e o que Y havia dado para Z. &nbsp;Y e Z gastaram, cada uma, a diferença entre o quadrado doque Y havia dado a Z e 4 reais. Após esses gastos, a soma das quantias de X e Z era igual ao dobro da de Y.</p>\n<p>&nbsp;</p>\n<p>É correto afirmar que X gastou no total, em reais,</p>',
#   'subjectName': 'matematica',
#   'tags': ['Álgebra',
#    'Álgebra linear Função Funções Definidas por Várias Sentenças']}]

# %%
cursor

# %%
try:
    for doc in cursor:
        print(doc)
        questoes.append(doc)
finally:
    client.close()

# %%
# pd.DataFrame([w for w in cursor])

# %%
for q in questoes:
    print(q['tags'])
# Out:
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Composta Função Exponencial']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Afim Gráficos']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equação do Terceiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Cálculo diferencial integral Derivadas Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Equação do Terceiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais Trigonométricas']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Médias Ponderada']
# ['Álgebra', 'Médias Ponderada']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Médias Ponderada']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim Gráficos']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Inequações Inequações polinomiais']
# ['Álgebra', 'Função Função Bijetora']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Médias Ponderada']
# ['Álgebra', 'Médias Ponderada']
# ['Álgebra', 'Função']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Afim Função Exponencial']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Equação do Terceiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equação do Terceiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função Função Modular']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Modular']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Aritmética Médias Sequências']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Médias Ponderada']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Função Função Inversa']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Equação do Terceiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Inequação do Primeiro Grau Inequações Inequações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Inequação do Primeiro Grau Inequações Inequações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equação do Terceiro Grau Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Equação do Terceiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais Trigonométricas']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais Trigonométricas']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Expressões algébricas Função']
# ['Álgebra', 'Equações Expressões algébricas']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Médias Ponderada']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Médias Ponderada']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Médias Ponderada']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Bijetora Relações Binárias']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Inequação do Primeiro Grau Inequações Inequações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Inequação do Primeiro Grau Inequações Inequações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Exponencial Gráficos']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Médias Ponderada']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais Trigonométricas']
# ['Álgebra', 'Equação do Primeiro Grau Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função Relações Binárias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Exponencial Função Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Aritmética Médias Ponderada']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Equações Equações polinomiais Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Binômio de Newton']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Composta Função Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais Logarítmica']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Afim Gráficos']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Afim Função Exponencial']
# ['Álgebra', 'Inequação do Segundo Grau Inequações Inequações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Polinômio']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Inversa Funções Definidas por Várias Sentenças']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Polinômio']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Equações polinomiais']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Inequações Inequações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Composta Sequências']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Bijetora']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Inequações Inequações polinomiais Logarítmica']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Álgebra linear Função Polinomial']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Função Função Composta']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Inequação do Primeiro Grau Inequações Inequações polinomiais']
# ['Álgebra', 'Função Função Exponencial Função Logarítmica']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Polinômio']
# ['Álgebra', 'Polinômio']
# ['Álgebra', 'Polinômio']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Função']
# ['Álgebra', 'Polinômio']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Função']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Equação do Terceiro Grau Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais Trigonométricas']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Função Funções Definidas por Várias Sentenças']
# ['Álgebra', 'Equações Equações polinomiais Modular']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Equação do Terceiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Funções Definidas por Várias Sentenças']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Modular']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Inequação do Segundo Grau Inequações Inequações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Função Função Quadrática Médias']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Inequação do Primeiro Grau Inequações Inequações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Exponencial Inequações Inequações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais Modular']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Função Inversa']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Função Modular Gráficos']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Expressões algébricas Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Cálculo diferencial integral Limites']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Inversa']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações polinomiais']
# ['Álgebra', 'Polinômio']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim Gráficos']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Álgebra linear Inequações Inequações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função Função Quadrática Gráficos']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim Função Quadrática']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática Gráficos']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear Função Funções Definidas por Várias Sentenças']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função Função Quadrática Gráficos']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Inequação do Segundo Grau Inequações Inequações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais Polinomial Sequências']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Equações Equações polinomiais Trigonométricas']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Função Funções Definidas por Várias Sentenças']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Composta Função Exponencial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Quadrática Gráficos']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Inversa']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Inequações polinomiais']
# ['Álgebra', 'Expressões algébricas Polinômio']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Matemática financeira']
# ['Álgebra', 'Função']
# ['Álgebra', 'Expressões algébricas Função']
# ['Álgebra', 'Expressões algébricas Matemática financeira']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais Sequências']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Inequação do Primeiro Grau Inequações Inequações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Álgebra linear Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Função Afim Função Quadrática']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equações Equações polinomiais Trigonométricas']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Terceiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Inversa']
# ['Álgebra', 'Inequações Inequações polinomiais Modular']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equação do Terceiro Grau Equações Equações polinomiais Expressões algébricas']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Inversa']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais Função Inequações Inequações polinomiais']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função Função Composta']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função Função Composta']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Inversa']
# ['Álgebra', 'Função Função Composta Sequências']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais Função Função Quadrática']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Inequações Inequações polinomiais Logarítmica']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Funções Definidas por Várias Sentenças']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Inequação do Primeiro Grau Inequações Inequações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função Funções Definidas por Várias Sentenças']
# ['Álgebra', 'Função']
# ['Álgebra', 'Inequação do Segundo Grau Inequações Inequações polinomiais']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais Polinomial']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Equações Equações polinomiais Trigonométricas']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais Trigonométricas']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais Função Função Afim']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Inequação do Primeiro Grau Inequações Inequações polinomiais']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais Função Função Exponencial']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Médias']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Equação do Primeiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais Logarítmica']
# ['Álgebra', 'Função Função Modular']
# ['Álgebra', 'Equações Equações polinomiais Trigonométricas']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Equação do Terceiro Grau Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Função Paridade']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Polinomial']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Gráficos']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função Função Logarítmica']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Afim']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função']
# ['Álgebra', 'Equação do Segundo Grau Equações Equações polinomiais']
# ['Álgebra', 'Expressões algébricas']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Função Função Afim Função Quadrática Gráficos']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Álgebra linear Equações Equações polinomiais']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Função']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Exponencial']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Aritmética Médias']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Sequências']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Função Função Quadrática']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Álgebra linear']
# ['Álgebra', 'Equações Equações polinomiais']
# ['Álgebra', 'Equações Equações polinomiais Exponenciais']

# %%
    
df = pd.DataFrame([w for w in questoes])
df
# Out:
#                            _id  \
# 0     60b8f1433b844518e0e6ffde
# 1     60b8f14f3b844518e0e6ffe3
# 2     60b8f15e3b844518e0e6ffe7
# 3     60b8f15e3b844518e0e6ffea
# 4     60b8f15e3b844518e0e6ffeb
# ...                        ...
# 1418  60b95493132cbb4568a9037b
# 1419  60b9549c132cbb4568a9037d
# 1420  60b954a6132cbb4568a90383
# 1421  60b954b0132cbb4568a90389
# 1422  60b954b0132cbb4568a9038b
#
#                                                 options  \
# 0                                     [25, 50, 75, 150]
# 1         [R$ 0,45, R$ 0,40, R$ 0,38, R$ 0,35, R$ 0,30]
# 2     [10 dias., 12 dias., 13 dias., 14 dias., 15 di...
# 3     [α<em> </em>= -1, α<em> </em>= - 1/2, α<em> </...
# 4                              [30., 10., - 15., - 20.]
# ...                                                 ...
# 1418  [improvável., desfavorável., favorável., prová...
# 1419                    [– 64., – 42., – 36., 18., 24.]
# 1420  [<img class="formula" src="https://img.estuda....
# 1421  [possui três raízes naturais distintas.&nbsp;,...
# 1422  [0 e 1, 1 e 2, – 1 e 1&nbsp;, – 1 e 0&nbsp;, –...
#
#                                                    tags                key  \
# 0                             [Álgebra, Álgebra linear]  d_questao_1368122
# 1                         [Álgebra, Função Função Afim]  d_questao_1425146
# 2                  [Álgebra, Função Função Exponencial]  d_questao_1425169
# 3                                     [Álgebra, Função]  d_questao_1440557
# 4                                 [Álgebra, Sequências]  d_questao_1440578
# ...                                                 ...                ...
# 1418                [Álgebra, Função Função Quadrática]  d_questao_1253642
# 1419           [Álgebra, Equações Equações polinomiais]  d_questao_1253754
# 1420                          [Álgebra, Álgebra linear]  d_questao_1254254
# 1421           [Álgebra, Equações Equações polinomiais]  d_questao_1348923
# 1422  [Álgebra, Equações Equações polinomiais Expone...  d_questao_1362598
#
#                     name                      testName  \
# 0     Questão 17 1368122             PUC-RS Verão 2020
# 1      Questão 8 1425146                   UNIFOR 2020
# 2     Questão 12 1425169                   UNIFOR 2020
# 3     Questão 35 1440557                  UNICAMP 2020
# 4     Questão 37 1440578                  UNICAMP 2020
# ...                  ...                           ...
# 1418  Questão 13 1253642  FGV-SP Economia - Manhã 2017
# 1419  Questão 17 1253754  FGV-SP Economia - Manhã 2017
# 1420  Questão 25 1254254  FGV-SP Economia - Manhã 2017
# 1421  Questão 24 1348923                   ETEC 2017/2
# 1422  Questão 22 1362598                     FAAP 2017
#
#                                                 content  level  rightAnswer  \
# 0     <p>Um padeiro acabou de receber de um forneced...      0            2
# 1     <p>Uma pessoa pegou um táxi para ir ao trabalh...      0            1
# 2     <p>Em uma colônia de formigas, observou-se que...      0            0
# 3     <p>Sabendo que α é um número real, considere a...      0            0
# 4     <p>Considere que (<em>a, b</em>, 3,<em> c</em>...      0            2
# ...                                                 ...    ...          ...
# 1418  <p>O índice de Angstrom (IA), usado para alert...      1            3
# 1419  <p>A equação algébrica x<sup>3</sup> – 7x<sup>...      1            1
# 1420  <p>Na representação gráfica do sistema de equa...      1            2
# 1421  <p>No século XVI, divertidos duelos intelectua...      1            1
# 1422  <p>As soluções da equação exponencial 3<sup>2x...      1            2
#
#      subjectName               createdAt               updatedAt  __v
# 0     matematica 2021-06-03 15:12:03.762 2021-06-03 15:12:03.762    0
# 1     matematica 2021-06-03 15:12:15.693 2021-06-03 15:12:15.693    0
# 2     matematica 2021-06-03 15:12:30.540 2021-06-03 15:12:30.540    0
# 3     matematica 2021-06-03 15:12:30.711 2021-06-03 15:12:30.711    0
# 4     matematica 2021-06-03 15:12:30.771 2021-06-03 15:12:30.771    0
# ...          ...                     ...                     ...  ...
# 1418  matematica 2021-06-03 22:15:47.372 2021-06-03 22:15:47.372    0
# 1419  matematica 2021-06-03 22:15:56.982 2021-06-03 22:15:56.982    0
# 1420  matematica 2021-06-03 22:16:06.868 2021-06-03 22:16:06.868    0
# 1421  matematica 2021-06-03 22:16:16.763 2021-06-03 22:16:16.763    0
# 1422  matematica 2021-06-03 22:16:16.831 2021-06-03 22:16:16.831    0
#
# [1423 rows x 13 columns]

# %%
df[["subjectName","tags"]]
# Out:
#      subjectName                                               tags
# 0     matematica                          [Álgebra, Álgebra linear]
# 1     matematica                      [Álgebra, Função Função Afim]
# 2     matematica               [Álgebra, Função Função Exponencial]
# 3     matematica                                  [Álgebra, Função]
# 4     matematica                              [Álgebra, Sequências]
# ...          ...                                                ...
# 1418  matematica                [Álgebra, Função Função Quadrática]
# 1419  matematica           [Álgebra, Equações Equações polinomiais]
# 1420  matematica                          [Álgebra, Álgebra linear]
# 1421  matematica           [Álgebra, Equações Equações polinomiais]
# 1422  matematica  [Álgebra, Equações Equações polinomiais Expone...
#
# [1423 rows x 2 columns]
