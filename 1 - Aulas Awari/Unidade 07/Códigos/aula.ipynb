# %% [markdown]
# # Aula dia 16/06/2021

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('./foto.jpg')
#print(img)

imgplot = plt.imshow(img)

lum_img = img[:, :, :]

# This is array slicing.  You can read more in the `Numpy tutorial
# <https://docs.scipy.org/doc/numpy/user/quickstart.html>`_.

plt.imshow(lum_img)

#plt.imshow(lum_img, cmap="hot")

# %%
import pandas as pd

# %%
vr = pd.read_csv("./banco_de_imoveis/raw_data_10_jun.csv")
vr.values[0]
# Out:
# array(['2472650173',
#        'https://www.vivareal.com.br/imovel/apartamento-2-quartos-brooklin-zona-sul-sao-paulo-com-garagem-64m2-venda-RS715000-id-2472650173/',
#        'Apartamento com 2 Quartos à Venda, 64m²',
#        'Avenida Portugal, 401 - Brooklin, São Paulo - SP', '64',
#        '2 Quartos', '2 Banheiros', '1 Vaga',
#        'Elevador\nAr-condicionado\nPlayground\nMóvel planejado\nSalão de festas',
#        'R$ 715.000', 'R$ 778', 'Brooklin', '2021-06-10 16:17'],
#       dtype=object)

# %% [markdown]
# # API
